# %%
import os
import re
import operator
import nltk 
import numpy as np
import pandas as pd
import tensorflow as tf
import tensorflow_transform as tft

from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer

# Make numpy values easier to read.
np.set_printoptions(precision=3, suppress=True)

DATA_HOME = os.path.join('data/')
TRAIN_FILE_NAME = 'fulldocs.tsv'
# Out:
#                                                  Url  \
# 0  https://answers.yahoo.com/question/index?qid=2...
# 1  http://childparenting.about.com/od/physicalemo...
# 2             http://visihow.com/Check_for_Lice_Nits
# 3  http://www.nytimes.com/2010/01/05/business/glo...
# 4  http://www.realtor.com/realestateandhomes-sear...
#
#                                                Title  \
# 0  The hot glowing surfaces of stars emit energy ...
# 1  Developmental Milestones and Your 8-Year-Old C...
# 2                                Check for Lice Nits
# 3                    Dubai Opens a Tower to Beat All
# 4      Coulterville, CA Real Estate & Homes for Sale
#
#                                                 Body
# 0  Science & Mathematics PhysicsThe hot glowing s...
# 1  School-Age Kids Growth & DevelopmentDevelopmen...
# 2  Check for Lice NitsEdited by Mian Sheilette On...
# 3  Global BusinessDubai Opens a Tower to Beat All...
# 4  Coulterville, CA Real Estate & Homes for Sale4...

# %%
nrows = 100000

data_train = pd.read_csv(DATA_HOME + TRAIN_FILE_NAME, header=None, nrows=nrows, sep='\t')
data_train.columns = ['Url', 'Title', 'Body']

data_train.head()
# Out:
#                                                  Url  \
# 0  https://answers.yahoo.com/question/index?qid=2...
# 1  http://childparenting.about.com/od/physicalemo...
# 2             http://visihow.com/Check_for_Lice_Nits
# 3  http://www.nytimes.com/2010/01/05/business/glo...
# 4  http://www.realtor.com/realestateandhomes-sear...
#
#                                                Title  \
# 0  The hot glowing surfaces of stars emit energy ...
# 1  Developmental Milestones and Your 8-Year-Old C...
# 2                                Check for Lice Nits
# 3                    Dubai Opens a Tower to Beat All
# 4      Coulterville, CA Real Estate & Homes for Sale
#
#                                                 Body
# 0  Science & Mathematics PhysicsThe hot glowing s...
# 1  School-Age Kids Growth & DevelopmentDevelopmen...
# 2  Check for Lice NitsEdited by Mian Sheilette On...
# 3  Global BusinessDubai Opens a Tower to Beat All...
# 4  Coulterville, CA Real Estate & Homes for Sale4...

# %% [markdown]
# ### Load data

# %%
import ir_datasets
dataset = ir_datasets.load('msmarco-document')
# Out:
# [INFO] Please confirm you agree to the MSMARCO data usage agreement found at <http://www.msmarco.org/dataset.aspx>
# [INFO] If you have a local copy of https://msmarco.blob.core.windows.net/msmarcoranking/msmarco-docs.trec.gz, you can symlink it here to avoid downloading it again: C:\Users\marti\.ir_datasets\downloads\d4863e4f342982b51b9a8fc668b2d0c0
# [INFO] [starting] https://msmarco.blob.core.windows.net/msmarcoranking/msmarco-docs.trec.gz
# [INFO] [finished] https://msmarco.blob.core.windows.net/msmarcoranking/msmarco-docs.trec.gz: [1:00:43] [8.50GB] [2.33MB/s]

# %%
dataset_sample = dataset.docs_iter()[0:100000]
# Out:
# [INFO] [starting] building docstore
# docs_iter: 86262it [02:04, 694.85it/s]
# [INFO] [error] docs_iter: [02:04] [86262it] [694.83it/s]
# [INFO] [error] building docstore [02:04]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-185-de0241ee9c38> in <module>
# ----> 1 dataset_sample = dataset.docs_iter()[0:100000]
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\util\__init__.py in __getitem__(self, key)
#     141
#     142     def __getitem__(self, key):
# --> 143         return iter(self.docs_store)[key]
#     144
#     145
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\indices\lz4_pickle.py in __iter__(self)
#     272
#     273     def __iter__(self):
# --> 274         self.build()
#     275         return iter(self.lookup)
#     276
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\indices\lz4_pickle.py in build(self)
#     262         if not self.built():
#     263             with self.lookup.transaction() as trans, _logger.duration('building docstore'):
# --> 264                 for doc in _logger.pbar(self.init_iter_fn(), 'docs_iter'):
#     265                     trans.add(doc)
#     266
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\log.py in pbar(self, it, *args, **kwargs)
#      89         pbar = ir_datasets.lazy_libs.tqdm().tqdm(it, *args, **kwargs)
#      90         try:
# ---> 91             yield from pbar
#      92         except:
#      93             if not quiet:
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\tqdm\std.py in __iter__(self)
#    1176
#    1177         try:
# -> 1178             for obj in iterable:
#    1179                 yield obj
#    1180                 # Update and possibly print the progressbar.
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\util\__init__.py in __next__(self)
#     138
#     139     def __next__(self):
# --> 140         return next(self.it)
#     141
#     142     def __getitem__(self, key):
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\datasets\msmarco_document.py in docs_iter(self)
#      34     @ir_datasets.util.use_docstore
#      35     def docs_iter(self):
# ---> 36         for doc in super().docs_iter():
#      37             if isinstance(doc, MsMarcoDocument):
#      38                 # It's coming from the docstore
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\util\__init__.py in __next__(self)
#     138
#     139     def __next__(self):
# --> 140         return next(self.it)
#     141
#     142     def __getitem__(self, key):
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\formats\trec.py in docs_iter(self)
#      87             else:
#      88                 with self._docs_dlc.stream() as f:
# ---> 89                     yield from self._parser(f)
#      90
#      91     def _docs_iter(self, path):
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\ir_datasets\formats\trec.py in _parser_text(self, stream)
#     130         doc_id, doc_text = None, ''
#     131         in_tag = False
# --> 132         for line in f:
#     133             if line.startswith('<DOCNO>'):
#     134                 doc_id = line.replace('<DOCNO>', '').replace('</DOCNO>\n', '').strip()
#
# ~\AppData\Local\Programs\Python\Python38\lib\codecs.py in __next__(self)
#     643
#     644         """ Return the next decoded line from the input stream."""
# --> 645         line = self.readline()
#     646         if line:
#     647             return line
#
# ~\AppData\Local\Programs\Python\Python38\lib\codecs.py in readline(self, size, keepends)
#     556         # If size is given, we call read() only once
#     557         while True:
# --> 558             data = self.read(readsize, firstline=True)
#     559             if data:
#     560                 # If we're at a "\r" read one extra character (which might
#
# ~\AppData\Local\Programs\Python\Python38\lib\codecs.py in read(self, size, chars, firstline)
#     496                 newdata = self.stream.read()
#     497             else:
# --> 498                 newdata = self.stream.read(size)
#     499             # decode bytes (those remaining from the last call included)
#     500             data = self.bytebuffer + newdata
#
# ~\AppData\Local\Programs\Python\Python38\lib\gzip.py in read(self, size)
#     290             import errno
#     291             raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 292         return self._buffer.read(size)
#     293
#     294     def read1(self, size=-1):
#
# ~\AppData\Local\Programs\Python\Python38\lib\_compression.py in readinto(self, b)
#      66     def readinto(self, b):
#      67         with memoryview(b) as view, view.cast("B") as byte_view:
# ---> 68             data = self.read(len(byte_view))
#      69             byte_view[:len(data)] = data
#      70         return len(data)
#
# ~\AppData\Local\Programs\Python\Python38\lib\gzip.py in read(self, size)
#     485             buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
#     486
# --> 487             uncompress = self._decompressor.decompress(buf, size)
#     488             if self._decompressor.unconsumed_tail != b"":
#     489                 self._fp.prepend(self._decompressor.unconsumed_tail)
#
# KeyboardInterrupt:

# %%
len(dataset)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-187-8f70883cce9f> in <module>
# ----> 1 len(dataset)
#
# TypeError: object of type 'Dataset' has no len()

# %%
counter = 0
length = 10000
dataset_sample = []
for doc in dataset.docs_iter():
    if counter > length:
        break
    # print(doc)
    dataset_sample.append(doc)
    counter += 1

# %%
len(dataset_sample)
# Out:
# 10001

# %%
dataset_sample[0]
# Out:
# MsMarcoDocument(doc_id='D1555982', url='https://answers.yahoo.com/question/index?qid=20071007114826AAwCFvR', title='The hot glowing surfaces of stars emit energy in the form of electromagnetic radiation.?', body='Science & Mathematics Physics\nThe hot glowing surfaces of stars emit energy in the form of electromagnetic radiation.?\nIt is a good approximation to assume that the emissivity e is equal to 1 for these surfaces.\nFind the radius of the star Rigel, the bright blue star in the constellation Orion that radiates energy at a rate of 2.7 x 10^32 W and has a surface temperature of 11,000 K. Assume that the star is spherical.\nUse σ =... show more\nFollow 3 answers\nAnswers\nRelevance\nRating\nNewest\nOldest\nBest Answer: Stefan-Boltzmann law states that the energy flux by radiation is proportional to the forth power of the temperature: q = ε · σ · T^4 The total energy flux at a spherical surface of Radius R is Q = q·π·R² = ε·σ·T^4·π·R² Hence the radius is R = √ ( Q / (ε·σ·T^4·π) ) = √ ( 2.7x10+32 W / (1 · 5.67x10-8W/m²K^4 · (1100K)^4 · π) ) = 3.22x10+13 m\nSource (s):http://en.wikipedia.org/wiki/Stefan_bolt...schmiso · 1 decade ago0 18 Comment\nSchmiso, you forgot a 4 in your answer.\nYour link even says it: L = 4pi (R^2)sigma (T^4).\nUsing L, luminosity, as the energy in this problem, you can find the radius R by doing sqrt (L/ (4pisigma (T^4)).\nHope this helps everyone.\nCaroline · 4 years ago4 1 Comment (Stefan-Boltzmann law) L = 4pi*R^2*sigma*T^4 Solving for R we get: => R = (1/ (2T^2)) * sqrt (L/ (pi*sigma)) Plugging in your values you should get: => R = (1/ (2 (11,000K)^2)) *sqrt ( (2.7*10^32W)/ (pi * (5.67*10^-8 W/m^2K^4))) R = 1.609 * 10^11 m?\n· 3 years ago0 1 Comment\nMaybe you would like to learn more about one of these?\nWant to build a free website?\nInterested in dating sites?\nNeed a Home Security Safe?\nHow to order contacts online?\n\n')

# %%
train_queries = pd.read_csv(DATA_HOME + 'queries.doctrain.tsv', header=None, nrows=nrows, sep='\t')
train_queries.columns = ['qid', 'query']

train_top100 = pd.read_csv(DATA_HOME + 'msmarco-doctrain-top100', header=None, nrows=nrows, sep='\t')

train_queries.head()
# Out:
#        qid                                              query
# 0  1185869  )what was the immediate impact of the success ...
# 1  1185868  _________ justice is designed to repair the ha...
# 2  1183785                                     elegxo meaning
# 3   645590                     what does physical medicine do
# 4   186154         feeding rice cereal how many times per day

# %%
train_top100.head()
# Out:
#                                                    0
# 0  1185869 Q0 D59221 1 -4.80433 IndriQueryLikelihood
# 1  1185869 Q0 D59220 2 -4.92127 IndriQueryLikelihood
# 2  1185869 Q0 D2192591 3 -5.05215 IndriQueryLikel...
# 3  1185869 Q0 D2777518 4 -5.05486 IndriQueryLikel...
# 4  1185869 Q0 D2371978 5 -5.07048 IndriQueryLikel...

# %%
train_queries[train_queries['qid']==1185869]['query']
# Out:
# 0    )what was the immediate impact of the success ...
# Name: query, dtype: object

# %%
VOCAB_SIZE = 10000

def preprocessing_fn(inputs):
    """Preprocess input columns into transformed columns."""
    url = inputs['Url']
    title = inputs['Title']
    body = inputs['Body']
    
    print(body)
    
    tk = tf.keras.preprocessing.text.Tokenizer(num_words=VOCAB_SIZE)
    tk.fit_on_texts(body)

    tfidf_mat = tk.sequences_to_matrix(tk.texts_to_sequences(body), mode='tfidf')
    
    return {
        'tfidf_mat': tfidf_mat
    }

preprocessing_fn(data_train[:5])
# Out:
# 0    Science & Mathematics PhysicsThe hot glowing s...
# 1    School-Age Kids Growth & DevelopmentDevelopmen...
# 2    Check for Lice NitsEdited by Mian Sheilette On...
# 3    Global BusinessDubai Opens a Tower to Beat All...
# 4    Coulterville, CA Real Estate & Homes for Sale4...
# Name: Body, dtype: object
# {'tfidf_mat': array([[0.   , 2.522, 0.693, ..., 0.   , 0.   , 0.   ],
#         [0.   , 2.924, 3.332, ..., 0.   , 0.   , 0.   ],
#         [0.   , 4.198, 3.471, ..., 0.   , 0.   , 0.   ],
#         [0.   , 3.756, 3.003, ..., 0.   , 0.   , 0.   ],
#         [0.   , 0.   , 0.   , ..., 0.   , 0.   , 0.   ]])}

# %%
nltk.download('stopwords')

def is_number(s):
    try:
        float(s)
        return True
    except ValueError:
        return False

def filter_tokens(tokens, verbose=False):
    if verbose:
        print('Length before: {}'.format(len(tokens)))
    # Remove special char tokens
    tokens = [token for token in tokens if token not in '...,?:;·|``()&\'\'\'s____--']
    
    # Remove the ending of tokens ending with ".\d"
    tokens = [re.sub(r'\.\d', '', token) for token in tokens]
    
    # Remove trailing dots
    tokens = [token.rstrip('.') for token in tokens]

    # Remove trailing slashes
    tokens = [token.rstrip('/') for token in tokens]

    # Remove all empty and one letter tokens
    tokens = [token for token in tokens if not len(token) < 2]
    
    # Remove long words, which are most likely a concatination of several words
    word_max_length = 25
    tokens = [token for token in tokens if not len(token) > word_max_length]
    
    # Remove all nr tokens
    tokens = [token for token in tokens if not is_number(token)]
    
    # Remove math equations
    tokens = [token for token in tokens if not re.search(r'\^|·|π|\d+,\d+|\d\/|\+', token)]
    
    # Remove stopwords
    s_words = stopwords.words('english')
    tokens = [token for token in tokens if token not in s_words]
        
    # Split tokens where there is a dot between words
    new_tokens = []
    dot_regex = r'.{3,}\..'
    for token in tokens:
        if re.match(dot_regex, token):
            splitted_tokens = token.split('.')
            for s_token in splitted_tokens:
                new_tokens.append(s_token)
        else:
            new_tokens.append(token)
        
    tokens = new_tokens
    
    if verbose:
        print('Length after: {}'.format(len(tokens)))

    return tokens

test_tokens = ['science', '&', 'mathematics', 'physicsthe', 'hot', 'glowing', 'surfaces', 'of', 'stars', 'emit', 'energy', 'in', 'the', 'form', 'of', 'electromagnetic', 'radiation', '.', '?', 'it', 'is', 'a', 'good', 'approximation', 'to', 'assume', 'that', 'the', 'emissivity', 'e', 'is', 'equal', 'to', '1', 'for', 'these', 'surfaces', '.', 'find', 'the', 'radius', 'of', 'the', 'star', 'rigel', ',', 'the', 'bright', 'blue', 'star', 'in', 'the', 'constellation', 'orion', 'that', 'radiates', 'energy', 'at', 'a', 'rate', 'of', '2.7', 'x', '10^32', 'w', 'and', 'has', 'a', 'surface', 'temperature', 'of', '11,000', 'k.', 'assume', 'that', 'the', 'star', 'is', 'spherical', '.', 'use', 'σ', '=', '...', 'show', 'morefollow', '3', 'answersanswersrelevanceratingnewestoldestbest', 'answer', ':', 'stefan-boltzmann', 'law', 'states', 'that', 'the', 'energy', 'flux', 'by', 'radiation', 'is', 'proportional', 'to', 'the', 'forth', 'power', 'of', 'the', 'temperature', ':', 'q', '=', 'ε', '·', 'σ', '·', 't^4', 'the', 'total', 'energy', 'flux', 'at', 'a', 'spherical', 'surface', 'of', 'radius', 'r', 'is', 'q', '=', 'q·π·r²', '=', 'ε·σ·t^4·π·r²', 'hence', 'the', 'radius', 'is', 'r', '=', '√', '(', 'q', '/', '(', 'ε·σ·t^4·π', ')', ')', '=', '√', '(', '2.7x10+32', 'w', '/', '(', '1', '·', '5.67x10-8w/m²k^4', '·', '(', '1100k', ')', '^4', '·', 'π', ')', ')', '=', '3.22x10+13', 'msource', '(', 's', ')', ':', 'http', ':', '//en.wikipedia.org/wiki/stefan_bolt', '...', 'schmiso', '·', '1', 'decade', 'ago0', '18', 'commentschmiso', ',', 'you', 'forgot', 'a', '4', 'in', 'your', 'answer', '.', 'your', 'link', 'even', 'says', 'it', ':', 'l', '=', '4pi', '(', 'r^2', ')', 'sigma', '(', 't^4', ')', '.', 'using', 'l', ',', 'luminosity', ',', 'as', 'the', 'energy', 'in', 'this', 'problem', ',', 'you', 'can', 'find', 'the', 'radius', 'r', 'by', 'doing', 'sqrt', '(', 'l/', '(', '4pisigma', '(', 't^4', ')', ')', '.', 'hope', 'this', 'helps', 'everyone.caroline', '·', '4', 'years', 'ago4', '1', 'comment', '(', 'stefan-boltzmann', 'law', ')', 'l', '=', '4pi', '*', 'r^2', '*', 'sigma', '*', 't^4', 'solving', 'for', 'r', 'we', 'get', ':', '=', '>', 'r', '=', '(', '1/', '(', '2t^2', ')', ')', '*', 'sqrt', '(', 'l/', '(', 'pi', '*', 'sigma', ')', ')', 'plugging', 'in', 'your', 'values', 'you', 'should', 'get', ':', '=', '>', 'r', '=', '(', '1/', '(', '2', '(', '11,000k', ')', '^2', ')', ')', '*', 'sqrt', '(', '(', '2.7', '*', '10^32w', ')', '/', '(', 'pi', '*', '(', '5.67', '*', '10^-8', 'w/m^2k^4', ')', ')', ')', 'r', '=', '1.609', '*', '10^11', 'm', '?', '·', '3', 'years', 'ago0', '1', 'commentmaybe', 'you', 'would', 'like', 'to', 'learn', 'more', 'about', 'one', 'of', 'these', '?', 'want', 'to', 'build', 'a', 'free', 'website', '?', 'interested', 'in', 'dating', 'sites', '?', 'need', 'a', 'home', 'security', 'safe', '?', 'how', 'to', 'order', 'contacts', 'online', '?']
filter_tokens(test_tokens, True)
# Out:
# Length before: 379
# Length after: 121
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\marti\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ['science',
#  'mathematics',
#  'physicsthe',
#  'hot',
#  'glowing',
#  'surfaces',
#  'stars',
#  'emit',
#  'energy',
#  'form',
#  'electromagnetic',
#  'radiation',
#  'good',
#  'approximation',
#  'assume',
#  'emissivity',
#  'equal',
#  'surfaces',
#  'find',
#  'radius',
#  'star',
#  'rigel',
#  'bright',
#  'blue',
#  'star',
#  'constellation',
#  'orion',
#  'radiates',
#  'energy',
#  'rate',
#  'surface',
#  'temperature',
#  'assume',
#  'star',
#  'spherical',
#  'use',
#  'show',
#  'morefollow',
#  'answer',
#  'stefan-boltzmann',
#  'law',
#  'states',
#  'energy',
#  'flux',
#  'radiation',
#  'proportional',
#  'forth',
#  'power',
#  'temperature',
#  'total',
#  'energy',
#  'flux',
#  'spherical',
#  'surface',
#  'radius',
#  'hence',
#  'radius',
#  '1100k',
#  'msource',
#  'http',
#  'schmiso',
#  'decade',
#  'ago0',
#  'commentschmiso',
#  'forgot',
#  'answer',
#  'link',
#  'even',
#  'says',
#  '4pi',
#  'sigma',
#  'using',
#  'luminosity',
#  'energy',
#  'problem',
#  'find',
#  'radius',
#  'sqrt',
#  '4pisigma',
#  'hope',
#  'helps',
#  'everyone',
#  'caroline',
#  'years',
#  'ago4',
#  'comment',
#  'stefan-boltzmann',
#  'law',
#  '4pi',
#  'sigma',
#  'solving',
#  'get',
#  'sqrt',
#  'pi',
#  'sigma',
#  'plugging',
#  'values',
#  'get',
#  'sqrt',
#  'pi',
#  'years',
#  'ago0',
#  'commentmaybe',
#  'would',
#  'like',
#  'learn',
#  'one',
#  'want',
#  'build',
#  'free',
#  'website',
#  'interested',
#  'dating',
#  'sites',
#  'need',
#  'home',
#  'security',
#  'safe',
#  'order',
#  'contacts',
#  'online']

# %% [markdown]
# ### Preprocess Pandas data

# %%
import contractions

def preprocess_data():
    # Remove entries with "NaN" as body text
    data_train_new = data_train[data_train['Body'].notnull()]
    
    # Update the row indicies
    data_train_new = data_train_new.reset_index(drop=True)
    
    # Expand contractions
    for i, entry in enumerate(data_train_new['Body']):
        try:
            s = contractions.fix(entry)
        except Exception as e:
            print(i)
            print(data_train_new['Body'][i])
            print(data_train_new['Url'][i])
            print(repr(e))
        
    # data_train_new['Body'] = [contractions.fix(entry) for entry in data_train_new['Body']]
    
    # Lowercase
    data_train_new['Body'] = [entry.lower() for entry in data_train_new['Body']]
    
    # Remove any URLs from the text
    # Regex taken from here: https://gist.github.com/gruber/8891611
    url_regex = r'(?i)\b((?:https?:(?:/{1,3}|[a-z0-9%])|[a-z0-9.\-]+[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)/)(?:[^\s()<>{}\[\]]+|\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\))+(?:\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’])|(?:(?<!@)[a-z0-9]+(?:[.\-][a-z0-9]+)*[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)\b/?(?!@)))'
    data_train_new['Body'] = [re.sub(url_regex, ' ', entry) for entry in data_train_new['Body']]
        
    # Tokenize
    data_train_new['Word tokenize'] = [filter_tokens(word_tokenize(entry)) for entry in data_train_new['Body']]
        
    # print(data_train_new['Word tokenize'][:5])
    # print(data_train_new['Word tokenize'][0])
    
    return data_train_new
    
    
data_train_processed = preprocess_data()
# Out:
# 2675
# Local News Atlanta PoliticsPresident Obama’s mixed record of minority judicial appointeesBy David A. Love - February 6, 2014tweetPresident Barack Obama speaks while nominating Cornelia T. L. Pillard (2nd-L), a law professor, Patricia Ann Millett (R), an appellate lawyer, and Robert L. Wilkins (L), to become federal judges, during an event in the Rose Garden of the White House June 4, 2013 in Washington, DC. If confirmed by the U.S. Senate the three nominees will fill three vacancies on United States Court of Appeals for the District of Columbia. (Photo by Mark Wilson/Getty Images)How is President’s Obama’s record on diversity among judicial nominees?If you ask members of the Congressional Black Caucus and some civil rights leaders, they will say the president falls short when it comes to minorities on the federal bench, especially in states such as Georgia. But that’s only part of the story. Obama has a record of accomplishment on diverse appointees, but he made a deal in Georgia that came up smelling not so great. The devil’s in the details.Members of the CBC met with White House adviser Valerie Jarrett on Wednesday to voice their concerns about a dearth of federal judges of color. They believe that in Southern states, Obama has conceded too much to conservative Republican senators who they believe clash with the judicial philosophy of a typical Obama nominee. As a result, the judicial picks in states such as Georgia do not reflect the diversity of the jurisdictions they serve. The CBC wants the president to fight against GOP obstructionism.Blame it on the blue slip.Although the filibuster was killed in the Senate, and judicial nominees are now confirmed by a simple majority, the blue-slip process still remains . Under this obscure and arguably anachronistic system, a president can go forward with a nominee only if the senators in the candidate’s home state approve. This effectively gives Republican lawmakers veto power and undue influence over Obama’s appointments, even as a president should be able to promote the jurists of his choice.Back to that deal the president made in Georgia. As Think Progress reported, President Obama made an agreement with Senators Saxby Chambliss (R-Georgia) and Johnny Isakson (R-Georgia). The senators agreed to stop blocking Jill Pryor’s nomination to the Eleventh Circuit Court of Appeals—as they had done for years—and the administration agreed to give most of the six judicial vacancies in Georgia to the Republicans.Obama appointed Chief Judge Julie Carnes of the Northern District of Georgia, a George H.W. Bush nominee, to the appeals court, opening a fourth seat on the lower district court. Under the deal, Chambliss and Isakson were allowed to select three of the four vacancies.Two of the most objectionable Republican choices include two nominees for the district court level— Mark Cohen, who was a lead attorney defending Georgia’s discriminatory voter ID law in court, and state appeals Judge Michael Boggs, who as a legislator voted against same-sex marriage, supported abortion restrictions, and favored keeping the Confederate battle emblem on the Georgia state flag.Only one of the nominees from Georgia, Eleanor Ross, is black, and reportedly a Republican, in a state that is nearly one-third African-American. So, with all of the black people living in cities such as Atlanta, it is understandable that black Georgia lawmakers such as Reps. John Lewis, Hank Johnson and David Scott, and civil rights leaders such as Revs. Joseph Lowery and C. T. Vivian are concerned.However, the Obama administration has rightly pointed out the Republican obstruction of the president’s nominees. For example, in 2011, the Georgia senators blocked a black woman, Natasha Silas, to fill a district court seat. In North Carolina, Republican Senator Richard Burr has used the blue slip to block Jennifer May-Parker, another African-American woman, for consideration.And last year, Sen. Marco Rubio (R-Florida) blocked the appoint ...
# http://thegrio.com/2014/02/06/president-obamas-mixed-record-of-minority-judicial-appointees/
# IndexError('string index out of range')
# 2818
# İzmir, historically Smyrna, city in western Turkey. The country’s third largest city and one of its largest ports, İzmir lies at the head of the sheltered Gulf of İzmir on the deeply indented coast of the Aegean Sea. Pop. (2000) 2,232,265; (2013 est.) 2,803,418.Clock tower, İzmir, Turkey.Fritz Henle/Photo ResearchersHistoryİzmir is one of the oldest cities of the Mediterranean world and has been of almost continuous historical importance during the last 5,000 years. Excavations indicate settlement contemporary with that of the first city of Troy, dating from the 3rd millennium bce. Greek settlement is first clearly attested by the presence of pottery dating from about 1000 bce. According to the Greek historian Herodotus, the Greek city was founded by Aeolians but soon was seized by Ionians. From modest beginnings, it grew into a stately city in the 7th century, with massive fortifications and blocks of two-storied houses.Captured by Alyattes of Lydia about 600 bce, it ceased to exist as a city for about 300 years until it was refounded by either Alexander the Great or his lieutenants in the 4th century bce at a new site on and around Mount Pagus (modern Kadifekale; 540 feet [165 metres]). It soon emerged as one of the principal cities of Asia Minor ( Anatolia) and was later the centre of a civil diocese in the Roman province of Asia, vying with Ephesus and Pergamum for the title “first city of Asia.” Roman emperors visited there, and it was celebrated for its wealth, beauty, library, school of medicine, and rhetorical tradition. The stream of Meles is associated in local tradition with Homer, who is reputed to have been born by its banks. Smyrna was one of the early seats of Christianity.Capital of the naval theme (province) of Samos under the Byzantine emperors, Smyrna was taken by the Turkmen Aydın principality in the early 14th century ce. After being conquered in turn by the Crusaders sponsored by Pope Clement VI and by the Central Asian conqueror Timur  (Tamerlane), it was annexed to the Ottoman Empire about 1425. Although severely damaged by earthquakes in 1688 and 1778, it remained a prosperous Ottoman port with a large European population.İzmir was occupied by Greek forces in May 1919 and recaptured by Turkish forces under Mustafa Kemal (later Kemal Atatürk) on September 9, 1922. The particular troops—be they Greek or Turkish—most responsible for the murder and mayhem that marked those events is open for debate, but the fact remains that İzmir was ravaged by fierce fighting. İzmir was then devastated further when a massive fire broke out three days after the Turks had recaptured the city.The contemporary cityThe modern city, with spacious avenues and buildings constructed since 1924, stands mainly on the small delta plain of the Kızılçullu (ancient Meles) River around the eastern end of the gulf and on the heights and ridges to the south. Karşıyaka  (formerly Kordelia) district, once a separate town across the gulf from central İzmir, now constitutes the northwestern extent of the city. Konak district is the commercial centre of İzmir; the city’s residential quarters are concentrated in Karantina and in Güzelyalı to the southwest and in Eşrefpaşa, north of the bazaar. South of the commercial centre lies Kadifekale (Mount Pagus), on which the old citadel of İzmir was built. Alsancak to the north is the site of the recently enlarged harbour, whereas industry is concentrated in suburbs along the gulf to the northeast.KarşıyakaKarşıyaka district of İzmir, Turkey.TembelejderhaAfter World War II İzmir grew rapidly, partly because of its location, for which it was selected as the site of the headquarters of the North Atlantic Treaty Organization ’s command for land forces in southeastern Europe. It also has a teacher-training school and the Aegean University, founded in 1955. Second only to the Istanbul region in industry, it produces foods, cement, cotton and woolen textiles and has petrochemical and engineering works. A lar ...
# https://www.britannica.com/place/Izmir
# IndexError('string index out of range')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-176-4168cc61e2d3> in <module>
#      37
#      38
# ---> 39 data_train_processed = preprocess_data()
#
# <ipython-input-176-4168cc61e2d3> in preprocess_data()
#      11     for i, entry in enumerate(data_train_new['Body']):
#      12         try:
# ---> 13             s = contractions.fix(entry)
#      14         except Exception as e:
#      15             print(i)
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\contractions\__init__.py in fix(s, leftovers, slang)
#      94 def fix(s, leftovers=True, slang=True):
#      95     ts = replacers[(leftovers, slang)]
# ---> 96     return ts.replace(s)
#      97
#      98
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\textsearch\__init__.py in replace(self, text, return_entities)
#     559             stop = end_index + 1
#     560             for compare, keep_result, handler in handlers:
# --> 561                 if compare and compare is not norm:
#     562                     continue
#     563                 start, stop, result = handler(text, start, stop, norm)
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\textsearch\__init__.py in bounds_check(self, text, start, stop, norm)
#     369
#     370     def bounds_check(self, text, start, stop, norm):
# --> 371         if stop >= len(text):
#     372             return None, None, None
#     373         if len(text) != stop and text[stop] in self.right_bound_chars:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Preprocess data ir_datasets

# %%
import contractions

# Regex taken from here: https://gist.github.com/gruber/8891611
url_regex = r'(?i)\b((?:https?:(?:/{1,3}|[a-z0-9%])|[a-z0-9.\-]+[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)/)(?:[^\s()<>{}\[\]]+|\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\))+(?:\([^\s()]*?\([^\s()]+\)[^\s()]*?\)|\([^\s]+?\)|[^\s`!()\[\]{};:\'".,<>?«»“”‘’])|(?:(?<!@)[a-z0-9]+(?:[.\-][a-z0-9]+)*[.](?:com|net|org|edu|gov|mil|aero|asia|biz|cat|coop|info|int|jobs|mobi|museum|name|post|pro|tel|travel|xxx|ac|ad|ae|af|ag|ai|al|am|an|ao|aq|ar|as|at|au|aw|ax|az|ba|bb|bd|be|bf|bg|bh|bi|bj|bm|bn|bo|br|bs|bt|bv|bw|by|bz|ca|cc|cd|cf|cg|ch|ci|ck|cl|cm|cn|co|cr|cs|cu|cv|cx|cy|cz|dd|de|dj|dk|dm|do|dz|ec|ee|eg|eh|er|es|et|eu|fi|fj|fk|fm|fo|fr|ga|gb|gd|ge|gf|gg|gh|gi|gl|gm|gn|gp|gq|gr|gs|gt|gu|gw|gy|hk|hm|hn|hr|ht|hu|id|ie|il|im|in|io|iq|ir|is|it|je|jm|jo|jp|ke|kg|kh|ki|km|kn|kp|kr|kw|ky|kz|la|lb|lc|li|lk|lr|ls|lt|lu|lv|ly|ma|mc|md|me|mg|mh|mk|ml|mm|mn|mo|mp|mq|mr|ms|mt|mu|mv|mw|mx|my|mz|na|nc|ne|nf|ng|ni|nl|no|np|nr|nu|nz|om|pa|pe|pf|pg|ph|pk|pl|pm|pn|pr|ps|pt|pw|py|qa|re|ro|rs|ru|rw|sa|sb|sc|sd|se|sg|sh|si|sj|Ja|sk|sl|sm|sn|so|sr|ss|st|su|sv|sx|sy|sz|tc|td|tf|tg|th|tj|tk|tl|tm|tn|to|tp|tr|tt|tv|tw|tz|ua|ug|uk|us|uy|uz|va|vc|ve|vg|vi|vn|vu|wf|ws|ye|yt|yu|za|zm|zw)\b/?(?!@)))'

def create_tokens(body):
    # Expand contractions       
    try:
        body = contractions.fix(body)
    except Exception as e:
        print(body)
    
    # body = ' '.join([contractions.fix(word) for word in body.split()])

    # Lowercase
    body = body.lower()

    # Remove any URLs from the text
    body = re.sub(url_regex, ' ', body)    

    # Tokenize
    tokens = filter_tokens(word_tokenize(body))
    
    return tokens
    
def preprocess_dataset():
    # Remove entries that don't have strings as body text
    dataset_new = [entry for entry in dataset_sample if isinstance(entry[3], str)]
    
    # Update the row indicies
    # data_train_new = data_train_new.reset_index(drop=True)
    
    tokens_dict = {}
    for entry in dataset_new:
        tokens_dict[entry[0]] = create_tokens(entry[3])
        
    return tokens_dict
    
    
dataset_processed = preprocess_dataset()
# Out:
# İzmir, historically Smyrna, city in western Turkey.
# The country’s third largest city and one of its largest ports, İzmir lies at the head of the sheltered Gulf of İzmir on the deeply indented coast of the Aegean Sea.
# Pop.
# (2000) 2,232,265; (2013 est.)
# 2,803,418.
# Clock tower, İzmir, Turkey.
# Fritz Henle/Photo Researchers
# Historyİzmir is one of the oldest cities of the Mediterranean world and has been of almost continuous historical importance during the last 5,000 years.
# Excavations indicate settlement contemporary with that of the first city of Troy, dating from the 3rd millennium bce.
# Greek settlement is first clearly attested by the presence of pottery dating from about 1000 bce.
# According to the Greek historian Herodotus, the Greek city was founded by Aeolians but soon was seized by Ionians.
# From modest beginnings, it grew into a stately city in the 7th century, with massive fortifications and blocks of two-storied houses.
# Captured by Alyattes of Lydia about 600 bce, it ceased to exist as a city for about 300 years until it was refounded by either Alexander the Great or his lieutenants in the 4th century bce at a new site on and around Mount Pagus (modern Kadifekale; 540 feet [165 metres]).
# It soon emerged as one of the principal cities of Asia Minor ( Anatolia) and was later the centre of a civil diocese in the Roman province of Asia, vying with Ephesus and Pergamum for the title “first city of Asia.” Roman emperors visited there, and it was celebrated for its wealth, beauty, library, school of medicine, and rhetorical tradition.
# The stream of Meles is associated in local tradition with Homer, who is reputed to have been born by its banks.
# Smyrna was one of the early seats of Christianity.
# Capital of the naval theme (province) of Samos under the Byzantine emperors, Smyrna was taken by the Turkmen Aydın principality in the early 14th century ce.
# After being conquered in turn by the Crusaders sponsored by Pope Clement VI and by the Central Asian conqueror Timur  (Tamerlane), it was annexed to the Ottoman Empire about 1425.
# Although severely damaged by earthquakes in 1688 and 1778, it remained a prosperous Ottoman port with a large European population.İzmir was occupied by Greek forces in May 1919 and recaptured by Turkish forces under Mustafa Kemal (later Kemal Atatürk) on September 9, 1922.
# The particular troops—be they Greek or Turkish—most responsible for the murder and mayhem that marked those events is open for debate, but the fact remains that İzmir was ravaged by fierce fighting.
# İzmir was then devastated further when a massive fire broke out three days after the Turks had recaptured the city.
# The contemporary city
# The modern city, with spacious avenues and buildings constructed since 1924, stands mainly on the small delta plain of the Kızılçullu (ancient Meles) River around the eastern end of the gulf and on the heights and ridges to the south.
# Karşıyaka  (formerly Kordelia) district, once a separate town across the gulf from central İzmir, now constitutes the northwestern extent of the city.
# Konak district is the commercial centre of İzmir; the city’s residential quarters are concentrated in Karantina and in Güzelyalı to the southwest and in Eşrefpaşa, north of the bazaar.
# South of the commercial centre lies Kadifekale (Mount Pagus), on which the old citadel of İzmir was built.
# Alsancak to the north is the site of the recently enlarged harbour, whereas industry is concentrated in suburbs along the gulf to the northeast.
# Karşıyaka
# Karşıyaka district of İzmir, Turkey.
# Tembelejderha
# After World War II İzmir grew rapidly, partly because of its location, for which it was selected as the site of the headquarters of the North Atlantic Treaty Organization ’s command for land forces in southeastern Europe.
# It also has a teacher-training school and the Aegean University, founded in 1955.
# Second only to the Istanbul region in industry, it produces foods, cement, cotton and woolen textiles and has petrochemical and engineering works.
# A large international trade fair is held there annually.
# Exports include agricultural products from its hinterland—chiefly tobacco, figs, cotton, and vegetables —as well as manufactures, carpets, and silk.
# The city’s landmarks include the partly excavated remains of its agora and the ancient aqueducts of Kızılçullu.
# The archaeological museum has a fine collection of local antiquities.
# Situated near such famous ancient sites as Ephesus and Pergamum and numerous holiday resorts, İzmir has a growing tourist trade.İzmir is located in one of Turkey’s most densely populated areas.
# The coastal region includes the irrigated and fertile valleys and delta plains of the Küçükmenderes and Gediz rivers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-204-36cbfb58c810> in <module>
#      38
#      39
# ---> 40 dataset_processed = preprocess_dataset()
#
# <ipython-input-204-36cbfb58c810> in preprocess_dataset()
#      33     tokens_dict = {}
#      34     for entry in dataset_new:
# ---> 35         tokens_dict[entry[0]] = create_tokens(entry[3])
#      36
#      37     return tokens_dict
#
# <ipython-input-204-36cbfb58c810> in create_tokens(body)
#      20
#      21     # Tokenize
# ---> 22     tokens = filter_tokens(word_tokenize(body))
#      23
#      24     return tokens
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\nltk\tokenize\__init__.py in word_tokenize(text, language, preserve_line)
#     129     """
#     130     sentences = [text] if preserve_line else sent_tokenize(text, language)
# --> 131     return [
#     132         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     133     ]
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\nltk\tokenize\__init__.py in <listcomp>(.0)
#     130     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     131     return [
# --> 132         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     133     ]
#
# e:\documents\nlp\trec2021_deeplearningtrack\venv\lib\site-packages\nltk\tokenize\destructive.py in tokenize(self, text, convert_parentheses, return_str)
#     106     def tokenize(self, text, convert_parentheses=False, return_str=False):
#     107         for regexp, substitution in self.STARTING_QUOTES:
# --> 108             text = regexp.sub(substitution, text)
#     109
#     110         for regexp, substitution in self.PUNCTUATION:
#
# KeyboardInterrupt:

# %%
data_train.loc[2675, 'Body']
# Out:
# 'Monosaccharides> Monosaccharides, Biology | AssignmentsQuestion-What type of bond holds the two monosaccharides together in a disaccharide?a) Ester bondb) Hydrogen bondc) Amide bondd) Ether bond (or glycosidic bond)e) Intermolecular bond.Posted Date: 2/24/2014 12:46:16 AM | Location : United Kingdom (UK)Excel in your CourseExperts are helping students not just improving grades but also to provide better learning of subject concepts and its problem statements. They are providing you world class assistance which may help you to excel in course or assignments.Tutor service in UK?UK Assignment HelpUK Assessments HelpUK Custom Writing ServicesHelp with UK StudiesPaper/Essay Editing-FormattingManagement/Programming/Engineering HelpOrder NowMost Recent PostsUK Perdisco Assignment Help, UK PERDISCO Practice Set HelpUniversity of Brighton, Assignment Help, Tutor Help UKUniversity for the Creative Arts, Assignment Help UKThe University of Warwick, Assignment Help UKUniversity of Bradford Assignment Help, Tutor Service UKUniversity of Abertay Dundee, Assignment Help UKThe Arts University College of Bournemouth, Assignment HelpThe University of Sheffield, Assignment Help, UK Tutors HelpThe University of Bradfordshire, Assignment HelpUniversity of Aberdeen, Assignment Help, UK TutorsPopular TagsUK Studies UK Tutor ServiceUK Assignment HelpManagement Studies in UKHomework Help UK Assignment HelpUK University Assignment HelpAssessments SolutionHomework Solution UK WritersUK English Thesis'

# %%
data_train_processed.loc[1, 'Url']
# Out:
# 'http://childparenting.about.com/od/physicalemotionalgrowth/tp/Child-Development-Your-Eight-Year-Old-Child.htm'

# %%
data_train_processed.loc[1, 'Body']
# Out:
# 'school-age kids growth & developmentdevelopmental milestones and your 8-year-old child8-year-olds are expanding their worldsby katherine lee | reviewed by joel forman, mdupdated february 10, 2018share pin emailprinteight-year-olds are becoming more confident about themselves and who they are. at age 8, your child will likely have developed some interests and hobbies and will know what he or she likes or does not   the same time, children this age are learning more about the world at large and are also better able to navigate social relationships with others more independently, with less guidance from parents. at home, 8-year-olds are able to tackle more complicated household chores and take on more responsibility for taking care of themselves, even helping out with younger   general, according to the cdc, these are some changes you may see in your child:shows more independence from parents and family.starts to think about the future.understands more about his or her place in the world.pays more attention to friendships and teamwork.wants to be liked and accepted by friends.1 behavior and daily routinesfabrice lerouge/getty imagesthe 8-year-old\'s behavior and daily routines are shaped by the child\'s taste, interests, and personality. parents and other significant adults in the child\'s life should keep in mind the importance of being good role models since this is a time when children are figuring out the world and who they are and how they fit into it. at this age, your child may get involved with more complex social activities and behaviors that help define his or her sense of self.effective discipline techniques at this age include continuing to praise good behavior, focusing your child\'s efforts, what they can do and change, rather than innate traits (such as "you are smart"). set up and enforce consistent rules. discipline should be aimed at guiding your child rather than punishing. follow it with a discussion with your child about what she could do differently next time.your 8-year-old can do more self-care in regards to hygiene and may begin to want to be part of deciding what the family eats. you might begin to give your child chores to contribute to the maintenance of the household and an allowance to begin to learn to manage money. at this age, your child still needs 10 to 11 hours of sleep per night.2 physical developmentimage source/getty imagesfor 8-year-old children, physical development will continue to be more about refinement of skills, coordination, and muscle control rather than huge changes. they begin to look like "big kids," but puberty is still a couple of years away for most of them.children with natural athletic potential may show their abilities at this developmental stage as their physical skills become more precise and accurate. in fact, this is often the age at which children decide whether they are athletic or not, and choose to participate in or avoid sports. either way, it is important for parents to encourage physical activity. even if your child is not an athlete she can still enjoy running, swimming, biking, and many other types of non-sports-related physical fun.3 emotional developmentjohn howard/getty imageseight-year-old emotional development may be growing at a deeper level than in younger years, and an 8-year-old may show more sophisticated and complex emotions and interactions. for instance, an 8-year-old may mask true thoughts or emotions to spare someone else\'s feelings or work through a problem without an adult\'s close supervision or intervention.this is the time when your child may be developing a more sophisticated sense of himself in the world. her interests, talents, friends, and relationship with family all help her to establish a clear self-identity. it is also the beginning of desiring privacy and flip-flopping between self-confidence and   can be a good time to help your child develop patience and empathy for others.4 cognitive developmenttom merton/getty imageseight-yea ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import operator

## Create Vocabulary
vocabulary = set()

for doc in data_train_processed['Word tokenize']:
    vocabulary.update(doc)

vocabulary = list(vocabulary)

# Intializating the tfIdf model
tfidf = TfidfVectorizer(vocabulary=vocabulary)

# Fit the TfIdf model
tfidf.fit(data_train_processed['Body'])

# Transform the TfIdf model
tfidf_tran=tfidf.transform(data_train_processed['Body'])

# %%
vocab_count = dict()

for doc in data_train_processed['Word tokenize']:
    for token in doc:
        if token not in vocab_count:
            vocab_count[token] = 1
        else:
            vocab_count[token] += 1
    
vocab_count = dict(sorted(vocab_count.items(), key=lambda item: item[1], reverse=True))
vocab_count
# Out:
# {'also': 1265,
#  'one': 1041,
#  'may': 1002,
#  'new': 774,
#  'time': 767,
#  'use': 731,
#  'see': 629,
#  'would': 611,
#  'like': 559,
#  'people': 543,
#  'day': 543,
#  'used': 537,
#  'two': 535,
#  'first': 534,
#  'edit': 512,
#  'many': 474,
#  'need': 447,
#  'get': 439,
#  'world': 439,
#  'fallacy': 438,
#  'make': 435,
#  'control': 432,
#  'system': 432,
#  'the': 429,
#  'data': 422,
#  'years': 416,
#  'year': 404,
#  'even': 401,
#  'us': 385,
#  'using': 370,
#  'information': 355,
#  'earned': 343,
#  'states': 337,
#  'well': 334,
#  'card': 334,
#  'good': 330,
#  'work': 328,
#  'back': 321,
#  'state': 321,
#  'found': 315,
#  'light': 308,
#  'much': 305,
#  'way': 304,
#  'high': 304,
#  'different': 302,
#  'retrieved': 300,
#  'help': 299,
#  'called': 298,
#  'united': 296,
#  'american': 294,
#  'made': 292,
#  'sd': 292,
#  'right': 287,
#  'days': 286,
#  'could': 285,
#  'within': 283,
#  'life': 281,
#  'order': 280,
#  'part': 280,
#  'name': 278,
#  'history': 278,
#  'type': 277,
#  'average': 277,
#  'europe': 276,
#  'another': 275,
#  'points': 272,
#  'must': 271,
#  'often': 270,
#  'however': 270,
#  'three': 268,
#  'free': 267,
#  'take': 267,
#  'pp': 267,
#  'best': 265,
#  'long': 261,
#  'health': 259,
#  'said': 256,
#  'including': 255,
#  'home': 254,
#  'around': 254,
#  'water': 252,
#  'place': 251,
#  'available': 251,
#  'service': 250,
#  'legion': 250,
#  'less': 248,
#  'last': 245,
#  'find': 244,
#  'group': 243,
#  'research': 242,
#  'study': 241,
#  'without': 240,
#  'know': 239,
#  'white': 239,
#  'small': 239,
#  'number': 238,
#  'known': 235,
#  'speed': 235,
#  'change': 234,
#  'full': 234,
#  'great': 232,
#  'dead': 232,
#  'crime': 230,
#  'important': 229,
#  'caesar': 228,
#  'still': 225,
#  'per': 225,
#  'medieval': 224,
#  'cards': 223,
#  'true': 221,
#  'go': 221,
#  'set': 220,
#  'include': 217,
#  'temperature': 216,
#  'person': 215,
#  'early': 215,
#  'disease': 214,
#  'form': 211,
#  'every': 210,
#  'example': 210,
#  'e.g': 209,
#  'large': 208,
#  'area': 208,
#  'common': 208,
#  'following': 207,
#  'you': 207,
#  'usually': 206,
#  'family': 204,
#  'law': 203,
#  'public': 203,
#  'medical': 203,
#  'age': 202,
#  'might': 202,
#  'show': 201,
#  'read': 201,
#  'support': 201,
#  'answer': 200,
#  'since': 200,
#  'middle': 200,
#  'want': 199,
#  'laser': 197,
#  'north': 196,
#  'view': 194,
#  'period': 194,
#  'body': 192,
#  'end': 192,
#  'city': 192,
#  'care': 191,
#  'company': 190,
#  'text': 190,
#  'file': 190,
#  'war': 188,
#  'program': 187,
#  'food': 182,
#  'point': 182,
#  'power': 180,
#  'children': 180,
#  'process': 180,
#  'value': 179,
#  'fan': 179,
#  'national': 179,
#  'next': 178,
#  'means': 178,
#  'business': 178,
#  'justice': 178,
#  'blood': 177,
#  'rate': 176,
#  'april': 176,
#  'test': 176,
#  'case': 175,
#  'better': 173,
#  'gun': 172,
#  'child': 169,
#  'given': 169,
#  'side': 169,
#  'inc': 169,
#  'times': 168,
#  'words': 168,
#  'based': 168,
#  'argument': 168,
#  'general': 167,
#  'top': 166,
#  'four': 165,
#  'hours': 164,
#  'past': 164,
#  'several': 163,
#  'later': 163,
#  'cells': 163,
#  'second': 162,
#  'thing': 162,
#  'think': 161,
#  'customer': 161,
#  'july': 161,
#  'pdf': 161,
#  'class': 160,
#  'university': 160,
#  'romania': 159,
#  'iridium': 159,
#  'english': 158,
#  'always': 157,
#  'cost': 156,
#  'although': 156,
#  'low': 156,
#  'current': 155,
#  'page': 155,
#  'standard': 155,
#  'open': 155,
#  'county': 155,
#  'services': 154,
#  'mean': 154,
#  'provide': 153,
#  'least': 153,
#  'local': 153,
#  'list': 153,
#  'never': 153,
#  'line': 153,
#  's': 153,
#  'possible': 152,
#  'specific': 152,
#  'word': 151,
#  'speech': 151,
#  'school': 150,
#  'range': 150,
#  'old': 150,
#  'note': 150,
#  'ages': 150,
#  'money': 149,
#  'skin': 149,
#  'related': 149,
#  'give': 148,
#  'certain': 148,
#  'laws': 148,
#  'language': 147,
#  'add': 146,
#  'article': 146,
#  'due': 146,
#  'access': 146,
#  'click': 145,
#  'march': 145,
#  'century': 145,
#  'level': 144,
#  'going': 144,
#  'empire': 144,
#  'say': 144,
#  'western': 144,
#  'nursing': 143,
#  'energy': 142,
#  'become': 142,
#  'size': 142,
#  'military': 142,
#  'cell': 142,
#  'create': 142,
#  'away': 141,
#  'little': 141,
#  'black': 141,
#  'doctor': 141,
#  'date': 141,
#  'isbn': 141,
#  'potion': 141,
#  'something': 140,
#  'social': 139,
#  'allow': 139,
#  'rates': 139,
#  'web': 139,
#  'june': 138,
#  'either': 137,
#  'step': 137,
#  'december': 137,
#  'field': 137,
#  'able': 136,
#  'come': 136,
#  'miles': 136,
#  'version': 136,
#  'making': 136,
#  'product': 136,
#  'human': 136,
#  'effects': 136,
#  'keep': 134,
#  'call': 134,
#  'records': 134,
#  'management': 134,
#  'look': 133,
#  'higher': 133,
#  'source': 133,
#  'tag': 133,
#  'rights': 132,
#  'though': 132,
#  'house': 132,
#  'late': 132,
#  'location': 132,
#  'income': 132,
#  'doi': 132,
#  'method': 131,
#  'south': 131,
#  'hobbs': 131,
#  'others': 130,
#  'yes': 130,
#  'material': 130,
#  'living': 130,
#  'society': 130,
#  'roman': 130,
#  'yom': 130,
#  'areas': 129,
#  'contact': 129,
#  'action': 129,
#  'today': 129,
#  'framework': 129,
#  'physical': 128,
#  'january': 128,
#  'million': 128,
#  'members': 128,
#  'press': 128,
#  'fields': 128,
#  'online': 127,
#  'changes': 127,
#  'needs': 127,
#  'whether': 127,
#  'months': 127,
#  'video': 127,
#  'done': 126,
#  'america': 126,
#  'among': 126,
#  'main': 126,
#  'heart': 126,
#  'memory': 126,
#  'things': 125,
#  'cooking': 125,
#  'major': 124,
#  'man': 124,
#  'french': 124,
#  'international': 124,
#  'et': 124,
#  'night': 123,
#  'problems': 123,
#  'table': 123,
#  'total': 122,
#  'start': 122,
#  'experience': 122,
#  'reference': 122,
#  'office': 121,
#  'index': 121,
#  'code': 121,
#  'build': 120,
#  'types': 120,
#  'let': 120,
#  'education': 120,
#  'function': 120,
#  'sure': 119,
#  'job': 119,
#  'private': 119,
#  'earth': 119,
#  'al': 119,
#  'loop': 119,
#  'science': 118,
#  'development': 118,
#  'natural': 118,
#  'products': 118,
#  'required': 118,
#  'women': 118,
#  'pain': 118,
#  'august': 118,
#  'big': 117,
#  'minutes': 117,
#  'question': 117,
#  'jewish': 117,
#  'original': 117,
#  'west': 117,
#  'population': 117,
#  'february': 116,
#  'near': 116,
#  'really': 116,
#  'please': 116,
#  'center': 116,
#  'according': 115,
#  'lower': 115,
#  'associated': 115,
#  'present': 114,
#  'government': 114,
#  'york': 114,
#  'course': 114,
#  'results': 114,
#  'status': 114,
#  'king': 114,
#  'position': 113,
#  'air': 113,
#  'wall': 113,
#  'raised': 113,
#  'helpful': 112,
#  'upon': 112,
#  'account': 112,
#  'play': 112,
#  'false': 112,
#  'students': 112,
#  'learn': 111,
#  'fact': 111,
#  'death': 111,
#  'real': 111,
#  'run': 111,
#  'rather': 110,
#  'pay': 110,
#  'parts': 110,
#  'share': 110,
#  'left': 110,
#  'land': 110,
#  'daily': 109,
#  'treatment': 109,
#  'easy': 109,
#  'base': 109,
#  'outside': 109,
#  'multiple': 109,
#  'try': 109,
#  'movement': 109,
#  'live': 109,
#  'sometimes': 109,
#  'dictionary': 109,
#  'single': 109,
#  'includes': 109,
#  'fat': 109,
#  'check': 108,
#  'amount': 108,
#  'tell': 107,
#  'effect': 107,
#  'located': 107,
#  'country': 107,
#  'software': 107,
#  'map': 107,
#  'east': 107,
#  'individual': 107,
#  'infor': 107,
#  'design': 106,
#  'news': 106,
#  'central': 106,
#  'october': 106,
#  'series': 106,
#  'gb': 106,
#  'comes': 105,
#  'put': 105,
#  'generally': 105,
#  'cases': 105,
#  'particular': 105,
#  'problem': 104,
#  'personal': 104,
#  'quality': 104,
#  'crew': 104,
#  'someone': 103,
#  'dry': 103,
#  'orders': 103,
#  'works': 103,
#  'features': 103,
#  'variable': 103,
#  'israel': 103,
#  'review': 102,
#  'november': 102,
#  'report': 102,
#  'severity': 102,
#  'questions': 102,
#  'weather': 102,
#  'key': 102,
#  'worth': 101,
#  'symptoms': 101,
#  'instead': 101,
#  'actually': 101,
#  'site': 101,
#  'complete': 101,
#  'ground': 101,
#  'led': 101,
#  'plan': 101,
#  'performance': 101,
#  'john': 101,
#  'learning': 100,
#  'muscle': 100,
#  'patient': 100,
#  'wrong': 100,
#  'terms': 100,
#  'fast': 100,
#  'especially': 100,
#  'provides': 100,
#  'simple': 100,
#  'leprosy': 100,
#  'added': 100,
#  'surface': 99,
#  'whole': 99,
#  'application': 99,
#  'conditions': 99,
#  'political': 99,
#  'community': 99,
#  'systems': 99,
#  'taking': 98,
#  'love': 98,
#  'makes': 98,
#  'market': 98,
#  'scientific': 98,
#  'languages': 98,
#  'story': 98,
#  'p.m': 98,
#  'enough': 97,
#  'five': 97,
#  'reason': 97,
#  'uses': 97,
#  'book': 97,
#  'write': 97,
#  'lines': 97,
#  'likely': 96,
#  'men': 96,
#  'various': 96,
#  'occur': 96,
#  'hard': 96,
#  'degree': 96,
#  'ft': 95,
#  'needed': 95,
#  'along': 95,
#  'college': 95,
#  'throughout': 95,
#  'device': 95,
#  'analysis': 95,
#  'association': 95,
#  'induction': 95,
#  'ponderosa': 95,
#  'close': 94,
#  'special': 94,
#  'month': 94,
#  'team': 94,
#  'force': 94,
#  'hand': 94,
#  'september': 94,
#  'price': 94,
#  'patients': 94,
#  'allows': 94,
#  'california': 94,
#  'suicide': 94,
#  'syteline': 94,
#  'clear': 93,
#  'host': 93,
#  'similar': 93,
#  'names': 93,
#  'latitude': 93,
#  'young': 93,
#  'difference': 93,
#  'potential': 92,
#  'ask': 92,
#  'popular': 92,
#  'causes': 92,
#  'search': 92,
#  'studies': 92,
#  'hot': 91,
#  'red': 91,
#  'heat': 91,
#  'feet': 91,
#  'turn': 91,
#  'dog': 91,
#  'require': 91,
#  'addition': 91,
#  'considered': 91,
#  'steel': 91,
#  'directly': 91,
#  'fire': 91,
#  'longitude': 91,
#  'head': 90,
#  'cover': 90,
#  'visit': 90,
#  'sales': 90,
#  'occurrences': 90,
#  'far': 89,
#  'regular': 89,
#  'already': 89,
#  'lot': 89,
#  'simply': 89,
#  'devices': 89,
#  'de': 89,
#  'brain': 89,
#  'object': 89,
#  'journal': 89,
#  'longer': 88,
#  'act': 88,
#  'normal': 88,
#  'what': 88,
#  'training': 88,
#  'typically': 88,
#  'increase': 88,
#  'macbeth': 88,
#  'entire': 87,
#  'cold': 87,
#  'methods': 87,
#  'additional': 87,
#  'google': 87,
#  'buy': 87,
#  'god': 87,
#  'purchase': 87,
#  'begrudge': 87,
#  'grass': 86,
#  'fate': 86,
#  'bill': 86,
#  'firearm': 86,
#  'shall': 86,
#  'values': 85,
#  'designed': 85,
#  'named': 85,
#  'production': 85,
#  'forms': 85,
#  'result': 85,
#  'benefits': 85,
#  'risk': 85,
#  'police': 85,
#  'autonomy': 85,
#  'mexico': 85,
#  'issue': 84,
#  'return': 84,
#  'taken': 84,
#  'structure': 84,
#  'weight': 84,
#  'variety': 84,
#  'practice': 84,
#  'bad': 84,
#  'across': 84,
#  'art': 84,
#  'theory': 84,
#  'rule': 84,
#  'role': 83,
#  'hair': 83,
#  'post': 83,
#  'serious': 83,
#  'anything': 83,
#  'cut': 83,
#  'green': 83,
#  'erp': 83,
#  'credit': 83,
#  'ginger': 83,
#  'groups': 82,
#  'a': 82,
#  'section': 82,
#  'evidence': 82,
#  'nature': 82,
#  'jews': 82,
#  'third': 82,
#  'unit': 82,
#  'contract': 82,
#  'nurses': 82,
#  'security': 81,
#  'president': 81,
#  'record': 81,
#  'companies': 81,
#  'began': 81,
#  'car': 81,
#  'character': 81,
#  'positive': 81,
#  'temperatures': 81,
#  'keyview': 81,
#  'produce': 80,
#  'media': 80,
#  'prevent': 80,
#  'match': 80,
#  'gas': 80,
#  'game': 80,
#  'cup': 80,
#  'bus': 80,
#  'link': 79,
#  'got': 79,
#  'net': 79,
#  'fall': 79,
#  'came': 79,
#  'final': 79,
#  'william': 79,
#  'insurance': 79,
#  'inventory': 79,
#  'costs': 79,
#  'plant': 79,
#  'nurse': 79,
#  'cthulhu': 79,
#  'follow': 78,
#  'avoid': 78,
#  'together': 78,
#  'almost': 78,
#  'took': 78,
#  'lost': 78,
#  'necessary': 78,
#  'weeks': 78,
#  'levels': 78,
#  'interest': 78,
#  'thus': 78,
#  'pm': 78,
#  'term': 78,
#  'sun': 78,
#  'latin': 78,
#  'canada': 78,
#  'sources': 77,
#  'direct': 77,
#  'consider': 77,
#  'stock': 77,
#  'department': 77,
#  'operation': 77,
#  'included': 77,
#  'content': 77,
#  'options': 77,
#  'largest': 77,
#  'files': 77,
#  'robert': 77,
#  'rome': 77,
#  'blue': 76,
#  'kids': 76,
#  'parents': 76,
#  'involved': 76,
#  'address': 76,
#  'color': 76,
#  'length': 76,
#  'properties': 76,
#  'ever': 76,
#  'measure': 76,
#  'technology': 76,
#  'determine': 76,
#  'pray': 76,
#  'says': 75,
#  'feel': 75,
#  'drug': 75,
#  'store': 75,
#  'half': 75,
#  'square': 75,
#  'became': 75,
#  'offer': 75,
#  'requires': 75,
#  'thought': 75,
#  'lead': 75,
#  'knowledge': 75,
#  'court': 75,
#  'radio': 75,
#  'northern': 75,
#  'impact': 75,
#  'understand': 75,
#  'applications': 75,
#  'sgt': 75,
#  'yet': 74,
#  'select': 74,
#  'condition': 74,
#  'property': 74,
#  'overall': 74,
#  'inches': 74,
#  'provided': 74,
#  'metal': 74,
#  'item': 74,
#  'david': 74,
#  'numbers': 74,
#  'cities': 74,
#  'ii': 74,
#  'receive': 73,
#  'short': 73,
#  'how': 73,
#  'safety': 73,
#  'looking': 73,
#  'created': 73,
#  'decision': 73,
#  'mostly': 73,
#  'programs': 73,
#  'plus': 73,
#  'eastern': 73,
#  'employee': 73,
#  'mm': 73,
#  'sense': 72,
#  'watch': 72,
#  'speeds': 72,
#  'pressure': 72,
#  'ways': 72,
#  'computer': 72,
#  'inside': 72,
#  'windows': 72,
#  'room': 72,
#  'modern': 72,
#  'equipment': 72,
#  'religious': 72,
#  'digital': 72,
#  'resources': 72,
#  'solar': 72,
#  'flour': 72,
#  'operator': 72,
#  'continue': 71,
#  'items': 71,
#  'easily': 71,
#  'stay': 71,
#  'countries': 71,
#  'party': 71,
#  'culture': 71,
#  'drugs': 71,
#  'sex': 71,
#  'transfer': 71,
#  'traditional': 71,
#  'guide': 71,
#  'church': 71,
#  'a.m': 71,
#  'save': 71,
#  'town': 71,
#  'future': 70,
#  'takes': 70,
#  'british': 70,
#  'france': 70,
#  'caused': 70,
#  'european': 70,
#  'professional': 70,
#  'industry': 70,
#  'travel': 70,
#  'medicine': 70,
#  'shows': 69,
#  'cycle': 69,
#  'steps': 69,
#  'remove': 69,
#  'starting': 69,
#  'percent': 69,
#  'gold': 69,
#  'larger': 69,
#  'details': 69,
#  'plants': 69,
#  'capacity': 69,
#  'command': 69,
#  'events': 69,
#  'primary': 69,
#  'observed': 69,
#  'reading': 69,
#  'edge': 69,
#  'elements': 69,
#  'former': 69,
#  'ancient': 69,
#  'meaning': 69,
#  'limited': 69,
#  'james': 69,
#  'week': 69,
#  'milk': 69,
#  'dr': 69,
#  'stars': 68,
#  'helps': 68,
#  'growth': 68,
#  'choose': 68,
#  'yes|': 68,
#  'no|': 68,
#  'apply': 68,
#  'working': 68,
#  'aircraft': 68,
#  'meat': 68,
#  'member': 68,
#  'definition': 68,
#  'degrees': 68,
#  'rest': 68,
#  'oxford': 68,
#  'marketing': 68,
#  '\\program': 68,
#  'discipline': 67,
#  'depending': 67,
#  'truth': 67,
#  'materials': 67,
#  'probably': 67,
#  'etc': 67,
#  'tests': 67,
#  'recent': 67,
#  'extended': 67,
#  'archived': 67,
#  'engineer': 67,
#  'sdxc': 67,
#  'remote': 67,
#  'complex': 66,
#  'building': 66,
#  'previous': 66,
#  'six': 66,
#  'requirements': 66,
#  'box': 66,
#  'england': 66,
#  'allowed': 66,
#  'reported': 66,
#  'ability': 66,
#  'percentage': 66,
#  'purpose': 66,
#  'matter': 66,
#  'transaction': 66,
#  'safe': 65,
#  'strong': 65,
#  'response': 65,
#  'greater': 65,
#  'locations': 65,
#  'player': 65,
#  'significant': 64,
#  'activities': 64,
#  'skills': 64,
#  'growing': 64,
#  'lice': 64,
#  'financial': 64,
#  'via': 64,
#  'contributionswhat': 64,
#  'firearms': 64,
#  'score': 64,
#  'season': 64,
#  'equal': 63,
#  'hold': 63,
#  'hotel': 63,
#  'economic': 63,
#  'mix': 63,
#  'unique': 63,
#  'increased': 63,
#  'customers': 63,
#  'foot': 63,
#  'roosevelt': 63,
#  'nothing': 63,
#  'subject': 63,
#  'anyone': 63,
#  'older': 63,
#  'claims': 63,
#  'answered': 63,
#  'established': 63,
#  'mode': 63,
#  'eat': 63,
#  'storage': 63,
#  'seen': 63,
#  'published': 63,
#  'tax': 63,
#  'contemporary': 63,
#  'copy': 63,
#  'everyone': 62,
#  'spread': 62,
#  'paper': 62,
#  'army': 62,
#  'tv': 62,
#  'chance': 62,
#  'phone': 62,
#  'believe': 62,
#  'functions': 62,
#  'legal': 62,
#  'paid': 62,
#  'context': 62,
#  'factors': 62,
#  'improve': 62,
#  'photos': 62,
#  'reduce': 62,
#  'reports': 62,
#  'currently': 62,
#  'families': 62,
#  'actions': 62,
#  'uk': 62,
#  'authoritarian': 62,
#  'pampas': 62,
#  'potions': 62,
#  'developed': 61,
#  'healthy': 61,
#  'highest': 61,
#  'ago': 61,
#  'offers': 61,
#  'wind': 61,
#  'prior': 61,
#  'forces': 61,
#  'released': 61,
#  'maintain': 61,
#  'seems': 61,
#  'movie': 61,
#  'washington': 61,
#  'produced': 61,
#  'thanks': 61,
#  'lock': 61,
#  'sdhc': 61,
#  'courier': 61,
#  'website': 60,
#  'behind': 60,
#  'issues': 60,
#  'basic': 60,
#  'move': 60,
#  'particularly': 60,
#  'model': 60,
#  'idea': 60,
#  'internet': 60,
#  'glass': 60,
#  'claim': 60,
#  'tools': 60,
#  'testing': 60,
#  'island': 60,
#  'figure': 60,
#  'mission': 60,
#  'georgia': 60,
#  'reduced': 60,
#  'distance': 60,
#  'historical': 60,
#  'drive': 60,
#  'style': 60,
#  'ed': 60,
#  'mary': 60,
#  'actual': 60,
#  'door': 60,
#  'cucumber': 60,
#  'cpl': 60,
#  'us.mary': 60,
#  'integra': 60,
#  'begin': 59,
#  'hour': 59,
#  'quickly': 59,
#  'kind': 59,
#  'held': 59,
#  'getting': 59,
#  'loss': 59,
#  'asked': 59,
#  'examples': 59,
#  'depends': 59,
#  'mass': 59,
#  'meet': 59,
#  'contain': 59,
#  'document': 59,
#  'crimes': 59,
#  'diamond': 59,
#  'email': 58,
#  'ca': 58,
#  ...}

# %%
vocab_count = dict(sorted(vocab_count.items(), key=lambda item: item[1]))
vocab_count
# Out:
# {'physicsthe': 1,
#  'emissivity': 1,
#  'rigel': 1,
#  'orion': 1,
#  'radiates': 1,
#  'morefollow': 1,
#  '1100k': 1,
#  'msource': 1,
#  'commentschmiso': 1,
#  'luminosity': 1,
#  '4pisigma': 1,
#  'ago4': 1,
#  'plugging': 1,
#  'school-age': 1,
#  'developmentdevelopmental': 1,
#  'child8-year-olds': 1,
#  'worldsby': 1,
#  'forman': 1,
#  'mdupdated': 1,
#  '2018share': 1,
#  'emailprinteight-year-olds': 1,
#  'hobbies': 1,
#  'teamwork': 1,
#  'routinesfabrice': 1,
#  'lerouge/getty': 1,
#  'figuring': 1,
#  'self-care': 1,
#  'developmentimage': 1,
#  'source/getty': 1,
#  'imagesfor': 1,
#  'puberty': 1,
#  'biking': 1,
#  'non-sports-related': 1,
#  'developmentjohn': 1,
#  'howard/getty': 1,
#  'self-identity': 1,
#  'flip-flopping': 1,
#  'self-confidence': 1,
#  'empathy': 1,
#  'developmenttom': 1,
#  'merton/getty': 1,
#  'eight-year-olds': 1,
#  'critically': 1,
#  'developmentchristopher': 1,
#  'futcher/getty': 1,
#  'imagesthis': 1,
#  'quirks': 1,
#  'pediatrician': 1,
#  'verywellyour': 1,
#  '8-10-year-olds': 1,
#  'chaplin': 1,
#  'aldao': 1,
#  'meta-analytic': 1,
#  ':735-765': 1,
#  'nitsedited': 1,
#  'mian': 1,
#  'sheilette': 1,
#  'ong': 1,
#  'other8': 1,
#  'licetreatment': 1,
#  'commentspersonal': 1,
#  'helpadeverything': 1,
#  'nitseven': 1,
#  'helplice': 1,
#  'infest': 1,
#  'parasite-free': 1,
#  'mingling': 1,
#  'helpa': 1,
#  'licerecognize': 1,
#  'arthropods': 1,
#  'six-legged': 1,
#  'invertebrates': 1,
#  'sesame': 1,
#  'mosquitoes': 1,
#  'headbands': 1,
#  'helpeggsthe': 1,
#  'helpby': 1,
#  'eggshells': 1,
#  'dandruff': 1,
#  'adhesives': 1,
#  'coloration': 1,
#  'brownish': 1,
#  'helplife': 1,
#  'licehead': 1,
#  '40-50': 1,
#  ':1': 1,
#  'helphow': 1,
#  'eggsyou': 1,
#  'itches': 1,
#  'helpfirst': 1,
#  'upholstered': 1,
#  'helpthe': 1,
#  'techniquedetecting': 1,
#  '5-15': 1,
#  'helpdry': 1,
#  'techniquethis': 1,
#  'detecting': 1,
#  'untangle': 1,
#  'cleared': 1,
#  'licepubic': 1,
#  'underarms': 1,
#  'mustaches': 1,
#  'beards': 1,
#  'lather': 1,
#  'up.was': 1,
#  'undergarments': 1,
#  'licebody': 1,
#  'liceafter': 1,
#  'ridding': 1,
#  'linens': 1,
#  'washable': 1,
#  'dry-cleaned': 1,
#  'helppersonal': 1,
#  'vigilant': 1,
#  'chemicalsthis': 1,
#  'needconditioner': 1,
#  'curling': 1,
#  'combed': 1,
#  'dollop': 1,
#  'bangs': 1,
#  'huddling': 1,
#  'thickly': 1,
#  'help11': 1,
#  'help12': 1,
#  'help13': 1,
#  'help14': 1,
#  '.throw': 1,
#  'nitsnow': 1,
#  'whomever': 1,
#  'helptips': 1,
#  'warningsdo': 1,
#  'commentsvisihow': 1,
#  'welcomes': 1,
#  'wellnessrecent': 1,
#  'engshare': 1,
#  'businessdubai': 1,
#  'allby': 1,
#  '2010a': 1,
#  'haider/european': 1,
#  'pressphoto': 1,
#  'agencyburdened': 1,
#  'doubling': 1,
#  'rocket-shaped': 1,
#  'edifice': 1,
#  'soars': 1,
#  'glittering': 1,
#  'mohammed': 1,
#  'rashid': 1,
#  'al-maktoum': 1,
#  'beaten-down': 1,
#  'collapsed': 1,
#  'occupants': 1,
#  'nightclubs': 1,
#  'mosques': 1,
#  'boardrooms': 1,
#  'armani': 1,
#  '76th': 1,
#  '158th': 1,
#  'coveragethe': 1,
#  '2010fireworks': 1,
#  'greet': 1,
#  'skyscraperbut': 1,
#  'proudly': 1,
#  'krane': 1,
#  'quid': 1,
#  'quo': 1,
#  'gratitude': 1,
#  'bailout': 1,
#  'festivities': 1,
#  'fireworks': 1,
#  '101': 1,
#  'zooming': 1,
#  'elevators': 1,
#  'skidmore': 1,
#  'owings': 1,
#  'merrill': 1,
#  'towering': 1,
#  'crowell/bloomberg': 1,
#  'newsbut': 1,
#  'doubters': 1,
#  '24-story': 1,
#  'all-new': 1,
#  'dealbook': 1,
#  'newsletterour': 1,
#  'columnist': 1,
#  'sorkin': 1,
#  'power-brokers': 1,
#  'policyopt': 1,
#  'anytimeaimed': 1,
#  'flagship': 1,
#  'forestall': 1,
#  'splintered': 1,
#  'leased': 1,
#  'handing': 1,
#  'speculators': 1,
#  'heartening': 1,
#  '2010an': 1,
#  'emir': 1,
#  'caption': 1,
#  'emirate': 1,
#  'coulterville': 1,
#  'sale40': 1,
#  'listings×there': 1,
#  'scouted': 1,
#  'homesmultiple': 1,
#  'waylisting': 1,
#  'berkshire': 1,
#  'hathaway': 1,
#  'homeservices-california': 1,
#  'realty-sonora24new': 1,
#  'sale3': 1,
#  'homecoin21new': 1,
#  'agentmultiple': 1,
#  'nlisting': 1,
#  'realty15pending': 1,
#  '95329land10': 1,
#  'remax': 1,
#  'diversified34pending': 1,
#  'agentfound': 1,
#  'argentinomiscellaneousthe': 1,
#  'pack-hunting': 1,
#  'bred': 1,
#  'big-game': 1,
#  'boar': 1,
#  'argentinocompare': 1,
#  'breed/s': 1,
#  'choosingpersonality': 1,
#  'courageousenergy': 1,
#  'dogos': 1,
#  'temperamental': 1,
#  'bestgood': 1,
#  'supervisiongood': 1,
#  'supervisionshedding': 1,
#  'infrequentgrooming': 1,
#  'occasionaltrainability': 1,
#  'wellheight': 1,
#  '24-27': 1,
#  '23-26': 1,
#  '80-100': 1,
#  'poundslife': 1,
#  'expectancy': 1,
#  '9-15': 1,
#  'yearsbarking': 1,
#  'barks': 1,
#  'necessarymeet': 1,
#  'argentinodid': 1,
#  'argentinian': 1,
#  'mastiff': 1,
#  'history1995the': 1,
#  'standardlearn': 1,
#  'herecolors': 1,
#  'markings10learn': 1,
#  'moreat': 1,
#  'glanceenergy': 1,
#  'sizemedium': 1,
#  'sizenational': 1,
#  'americafind': 1,
#  'puppiesthe': 1,
#  'standardembed': 1,
#  'flier': 1,
#  'pdfs1020304050607general': 1,
#  'appearancemolossian': 1,
#  'mesomorphic': 1,
#  'macrothalic': 1,
#  'harmonic': 1,
#  'carenutrition': 1,
#  'feedinggood': 1,
#  'puppyhood': 1,
#  'morecoat': 1,
#  'groomingthe': 1,
#  'moreexercisethe': 1,
#  'novice': 1,
#  'morehealthdogo': 1,
#  'moreget': 1,
#  'eventsnational': 1,
#  'americalocal': 1,
#  'clubsfind': 1,
#  'meetupsexplore': 1,
#  'argentinocane': 1,
#  'corso': 1,
#  'plott': 1,
#  'rhodesian': 1,
#  'ridgeback': 1,
#  'danebullmastiffexplore': 1,
#  'breedsby': 1,
#  'solutionsat': 1,
#  '9ntr146d': 1,
#  'staunch': 1,
#  'fabricating': 1,
#  'fabricator': 1,
#  'kevlar™': 1,
#  'erie': 1,
#  'galla': 1,
#  'presidentrecent': 1,
#  'articlesapril': 1,
#  '2018netting': 1,
#  'spectator': 1,
#  'sportsmarch': 1,
#  '2018safety': 1,
#  '2018defender': 1,
#  'ratingsjanuary': 1,
#  '2018dock': 1,
#  'docksnovember': 1,
#  '2017netting': 1,
#  'needgardening': 1,
#  'glovespre-emergent': 1,
#  'herbicideselective': 1,
#  'pre-emergent': 1,
#  '4-inch': 1,
#  'finer': 1,
#  'bulldog': 1,
#  'oratorical': 1,
#  'blackest': 1,
#  'fanatical': 1,
#  'mussolini': 1,
#  'caliber': 1,
#  'vice-president': 1,
#  'truman': 1,
#  'undertook': 1,
#  '2': 1,
#  'unprepared': 1,
#  'erupt': 1,
#  'maneuvers': 1,
#  'militantly': 1,
#  'isolationist': 1,
#  'wingers': 1,
#  'right-wingers': 1,
#  '.so': 1,
#  'warall': 1,
#  'woefully': 1,
#  'advocating': 1,
#  'magnified': 1,
#  'destroyers': 1,
#  'drafted': 1,
#  'lend-lease': 1,
#  'repayment': 1,
#  'haggle': 1,
#  '2.on': 1,
#  'dunkerque': 1,
#  'seventeen': 1,
#  'optimistic': 1,
#  'bitain': 1,
#  '2.just': 1,
#  'hesitancy': 1,
#  'expansionism': 1,
#  'commander-in': 1,
#  '2.prior': 1,
#  'awhile': 1,
#  'proceeded': 1,
#  'staffs': 1,
#  'wartime': 1,
#  'seniority': 1,
#  'enthusiastically': 1,
#  'squabbling': 1,
#  'now-delayed': 1,
#  'infuriated': 1,
#  'postponement': 1,
#  'hands-off': 1,
#  'thrusts': 1,
#  'underbelly': 1,
#  'galipoli': 1,
#  'meddler': 1,
#  'liddell': 1,
#  'flynn': 1,
#  'disagreed': 1,
#  'fervor': 1,
#  "'open": 1,
#  'pugnacious': 1,
#  'placate': 1,
#  'lengthened': 1,
#  'teheran': 1,
#  'yalta': 1,
#  'deviate': 1,
#  'communistic': 1,
#  'rebuilding': 1,
#  'revert': 1,
#  'deteriorating': 1,
#  'waffled': 1,
#  'blitzkrieg': 1,
#  'conclusionspresident': 1,
#  'policythis': 1,
#  'republished': 1,
#  'blogs': 1,
#  '2017last': 1,
#  'healthi': 1,
#  'swallowll': 1,
#  'crushing': 1,
#  'spoons': 1,
#  '~anonymous': 1,
#  'ratingask': 1,
#  'interferred': 1,
#  'spanner': 1,
#  'littlewing': 1,
#  'commentplease': 1,
#  'bosco': 1,
#  'vpn': 1,
#  'wavebreakmediaif': 1,
#  'compile': 1,
#  '20-year': 1,
#  'sternbeing': 1,
#  'overbearing': 1,
#  'overly': 1,
#  'platitudes': 1,
#  'ingratiates': 1,
#  'empowerment': 1,
#  'well…and': 1,
#  'madam': 1,
#  'shep': 1,
#  'hyken': 1,
#  'amaze': 1,
#  'notestake': 1,
#  'comcast': 1,
#  'antics': 1,
#  'chantay': 1,
#  'yourselfmost': 1,
#  'huehn': 1,
#  'briefwhen': 1,
#  'maynard': 1,
#  'succinct': 1,
#  'machacadobabylon': 1,
#  'dictionarydownload': 1,
#  'dictionarymachacadoadj': 1,
#  'laboredmachacarv': 1,
#  'dunk': 1,
#  'tediously': 1,
#  'nag': 1,
#  'swota': 1,
#  'spanish-english': 1,
#  '14download': 1,
#  'dictionarymachacado': 1,
#  'tennis': 1,
#  'starchy': 1,
#  'entree': 1,
#  'clobber': 1,
#  'ass/arse': 1,
#  'pulverise': 1,
#  '-usa': 1,
#  'mop': 1,
#  'cylinder': 1,
#  'platens': 1,
#  'tending': 1,
#  'slur': 1,
#  "'reorganizing": 1,
#  'heirarchy': 1,
#  "'dinosaurs": 1,
#  'catalogues': 1,
#  'clobbering': 1,
#  'revolving': 1,
#  'knives': 1,
#  'licked': 1,
#  'ill-armed': 1,
#  'guerillas': 1,
#  'scooping': 1,
#  'mashing': 1,
#  "'slaughtered": 1,
#  "'shredded": 1,
#  'arse': 1,
#  "'killers": 1,
#  'heigl': 1,
#  'mild-mannered': 1,
#  'gun-toting': 1,
#  'pulverizing': 1,
#  'triturator': 1,
#  'incorrectness': 1,
#  "'war": 1,
#  'pienso': 1,
#  'que': 1,
#  'gente': 1,
#  'tabarra': 1,
#  'demasiado': 1,
#  'sobre': 1,
#  'incorrección': 1,
#  'gramatical': 1,
#  'expresión': 1,
#  'terrorismo': 1,
#  'objeto': 1,
#  'eludir': 1,
#  'problema': 1,
#  'sarine': 1,
#  'mopped': 1,
#  'wringer': 1,
#  'freddy': 1,
#  'spuds': 1,
#  'lumps': 1,
#  'hammering': 1,
#  'tipos': 1,
#  'machacársela': 1,
#  'reflexivo': 1,
#  'wank': 1,
#  'jag': 1,
#  'mould': 1,
#  '25mm': 1,
#  'pathsuse': 1,
#  '7mm': 1,
#  '.formwork': 1,
#  'slurry': 1,
#  'formworkplywood': 1,
#  'reused': 1,
#  '2440mm': 1,
#  '1220mm': 1,
#  'nailed': 1,
#  'dampen': 1,
#  'boral': 1,
#  'bluescope': 1,
#  'measurementsonce': 1,
#  'diy': 1,
#  'oneill': 1,
#  'gorge': 1,
#  'washitonarmoryhistorian': 1,
#  'semikitkatyumyum': 1,
#  're-invented': 1,
#  'correctj': 1,
#  'helmretired': 1,
#  'virginiais': 1,
#  '…woodrow': 1,
#  '1912': 1,
#  'willia': 1,
#  '…david6023': 1,
#  'halper': 1,
#  'contributionsmedia': 1,
#  'democrat': 1,
#  'centrist': 1,
#  'leaned': 1,
#  '…veale': 1,
#  'urinate': 1,
#  'sneezes': 1,
#  'kegel': 1,
#  'weaken': 1,
#  'overgrowth': 1,
#  'lessened': 1,
#  'relaxants': 1,
#  'estrogens': 1,
#  'nighttime': 1,
#  'bed-wetting': 1,
#  '.behavioral': 1,
#  'urethra': 1,
#  'absorbent': 1,
#  'in-dwelling': 1,
#  'beyondoverviewwomen': 1,
#  'pelvis': 1,
#  '.abnormal': 1,
#  'uterusurinary': 1,
#  'infectionother': 1,
#  'conditionsuterine': 1,
#  'fibroidsgrowths': 1,
#  'canceralso': 1,
#  '.treatment': 1,
#  'causeschanges': 1,
#  'mid-30s': 1,
#  '.lighter': 1,
#  'ovulating': 1,
#  'menopausewhen': 1,
#  'diagnosisunusual': 1,
#  'dysfunctional': 1,
#  '.bleeding': 1,
#  'levelsno': 1,
#  'ovulation': 1,
#  'anovulation': 1,
#  'conditionsabnormal': 1,
#  'ovaries': 1,
#  'pid': 1,
#  'warts': 1,
#  'vulva': 1,
#  'vaginaurinary': 1,
#  'light-brown': 1,
#  'urineblood': 1,
#  'urinepain': 1,
#  'urinatingfrequent': 1,
#  'urinatethyroid': 1,
#  'prolactinoma': 1,
#  'cushing': 1,
#  'dryness': 1,
#  'causesgrowths': 1,
#  'oftenmenstrual': 1,
#  'crampsback': 1,
#  'painproblems': 1,
#  'urinationpain': 1,
#  'intercoursea': 1,
#  'polyp': 1,
#  'fingerlike': 1,
#  '.hormone-producing': 1,
#  'examblood': 1,
#  'testsultrasound': 1,
#  'examcancers': 1,
#  'swell': 1,
#  'itchingpaina': 1,
#  'anushemorrhoids': 1,
#  'hemorrhoid': 1,
#  'traumathe': 1,
#  'sextampon': 1,
#  'insertionstrenuous': 1,
#  'exerciseif': 1,
#  'bleedingmany': 1,
#  'periodsless': 1,
#  'bleedingskipped': 1,
#  'periodsmedications': 1,
#  'coumadin': 1,
#  'pillsbirth': 1,
#  'depo-provera': 1,
#  'contraceptive': 1,
#  'therapymedications': 1,
#  'antidepressantsseizure': 1,
#  'dilantin': 1,
#  'corticosteroids': 1,
#  'prednisone': 1,
#  'rejectionchemotherapy': 1,
#  'cytoxan': 1,
#  'tamoxifen': 1,
#  'therapythyroid': 1,
#  'synthroid': 1,
#  'levothroid': 1,
#  'us.help': 1,
#  'abuseunfortunately': 1,
#  'pressuring': 1,
#  '1-800-799-7233': 1,
#  '1-800-787-3224': 1,
#  'hearing/speech': 1,
#  '.visit': 1,
#  '1-800-656-4673': 1,
#  'conditionsbladder': 1,
#  'violencepdf': 1,
#  'relationshipif': 1,
#  'reimbursed': 1,
#  'totaled': 1,
#  'realizing': 1,
#  'at-fault': 1,
#  'insurer': 1,
#  'typessubrogation': 1,
#  'homeowner': 1,
#  'defective': 1,
#  'subrogate': 1,
#  'out-of-': 1,
#  'youwhy': 1,
#  'monies': 1,
#  'researches': 1,
#  'toll-free': 1,
#  '800-843-8550amis': 1,
#  'privileged': 1,
#  'amis': 1,
#  'omissions': 1,
#  'techvoice': 1,
#  'chrometech': 1,
#  'tipby': 1,
#  'biersdorfer': 1,
#  '2016microsoft': 1,
#  'timesq': 1,
#  'workarounds': 1,
#  'cortana-prompted': 1,
#  'fiddle': 1,
#  'loyalties': 1,
#  'of.k': 1,
#  'spoken-word': 1,
#  'totechtip': 1,
#  'circumventing': 1,
#  'analysisshare': 1,
#  'analysisformal': 1,
#  'cerebrospinal': 1,
#  'analysisrelated': 1,
#  'lactate': 1,
#  'afb': 1,
#  'rubella': 1,
#  'toxoplasmosis': 1,
#  'ebv': 1,
#  'beta-2': 1,
#  'microglobulin': 1,
#  'arbovirus': 1,
#  'testingall': 1,
#  'pagescommon': 1,
#  'antiseptic': 1,
#  'vertebrae': 1,
#  'vials': 1,
#  'post-test': 1,
#  'top2': 1,
#  'top3': 1,
#  'top4': 1,
#  'meningitis': 1,
#  'encephalitis•': 1,
#  'protein•': 1,
#  'virus•': 1,
#  'esr': 1,
#  'sedimentation': 1,
#  'crp': 1,
#  'c-reactive': 1,
#  'inflammation•': 1,
#  'cmp': 1,
#  'attentively': 1,
#  'hearer': 1,
#  'phrases6': 1,
#  'lottery': 1,
#  'overhear': 1,
#  'eavesdrop': 1,
#  'listenexpandmiddle': 1,
#  'english950before': 1,
#  'lis': 1,
#  'nen': 1,
#  'englishhlysnan': 1,
#  'lüsenen': 1,
#  'lyssna': 1,
#  '5related': 1,
#  'formsexpandlistener': 1,
#  'nounrelisten': 1,
#  'verbunlistening': 1,
#  'com1': 1,
#  '›geographyis': 1,
#  'emailprintpeace': 1,
#  'aguilera': 1,
#  'rosenbergupdated': 1,
#  '2018there': 1,
#  'delaware': 1,
#  '.taiwan': 1,
#  'nationalists': 1,
#  'basisabsolutely': 1,
#  'economyabsolutely': 1,
#  'educationabsolutely': 1,
#  'jade': 1,
#  'calligraphy': 1,
#  'peopleabsolutely': 1,
#  'pipelines': 1,
#  'railroads': 1,
#  'seaports': 1,
#  'powerabsolutely': 1,
#  'active-duty': 1,
#  'anti-secession': 1,
#  'sovereignty': 1,
#  'territorymostly': 1,
#  'countriessomewhat': 1,
#  'embassy': 1,
#  '1979': 1,
#  'unofficially': 1,
#  'instrumentality': 1,
#  'passports': 1,
#  'lobbied': 1,
#  'zoneforearm/crevice': 1,
#  'torso': 1,
#  'usespracticing': 1,
#  'mak': 1,
#  'aggressor': 1,
#  'axesmcreate': 1,
#  'axescollapse': 1,
#  'pagethe': 1,
#  'raster': 1,
#  'plotm': 1,
#  'geoshow': 1,
#  'queried': 1,
#  'setm': 1,
#  'xgrid': 1,
#  'ygrid': 1,
#  'xtick': 1,
#  'ytick': 1,
#  "'off'": 1,
#  "'on'": 1,
#  'toolbox™': 1,
#  'fig-file': 1,
#  'descriptionaxesm': 1,
#  'initiates': 1,
#  'modifies': 1,
#  "'fontsize',14": 1,
#  'projectioncreate': 1,
#  'functionaxesm': 1,
#  'name/property': 1,
#  'argumentscollapse': 1,
#  'allprojid': 1,
#  'idcharacter': 1,
#  "'eqdcylin'name-value": 1,
#  'argumentsspecify': 1,
#  'comma-separated': 1,
#  'name1': 1,
#  'value1': 1,
#  'namen': 1,
#  'valuen': 1,
#  "'pcarree": 1,
#  "'frame": 1,
#  'carree': 1,
#  "all'mapprojection": 1,
#  'projectioncharacter': 1,
#  'southern_limit': 1,
#  'northern_limit': 1,
#  'flatlimit': 1,
#  "'maplonlimit": 1,
#  'western_limit': 1,
#  'eastern_limit': 1,
#  'flonlimit': 1,
#  'tipsin': 1,
#  're-opening': 1,
#  'resetting': 1,
#  'right-clicking': 1,
#  'alsopropertiesmap': 1,
#  'propertiesfunctionsaxes': 1,
#  'gcm': 1,
#  'setmtopicsintroduction': 1,
#  'graphicsthe': 1,
#  'axesthe': 1,
#  'framemap': 1,
#  'propertiesthe': 1,
#  'gridintroduced': 1,
#  'r2006a': 1,
#  'afghanistansouthern': 1,
#  'asiaalbaniasouthern': 1,
#  'europealgerianorthern': 1,
#  'africaamerican': 1,
#  'europeangolamiddle': 1,
#  'americaarmeniawestern': 1,
#  'europeazerbaijanwestern': 1,
#  'asiabangladeshsouthern': 1,
#  'europebelgiumwestern': 1,
#  'europebelizecentral': 1,
#  'americabeninwestern': 1,
#  'africabermudanorthern': 1,
#  'americabhutansouthern': 1,
#  'asiabolivia': 1,
#  'plurinational': 1,
#  'americabonaire': 1,
#  'eustatius': 1,
#  'sabacaribbeanbosnia': 1,
#  'herzegovinasouthern': 1,
#  'europebotswanasouthern': 1,
#  'africabrazilsouth': 1,
#  'americabritish': 1,
#  'islandscaribbeanbrunei': 1,
#  'darussalamsouth-eastern': 1,
#  'asiabulgariaeastern': 1,
#  'europeburkina': 1,
#  'fasowestern': 1,
#  'africaburundieastern': 1,
#  'africacabo': 1,
#  'verdewestern': 1,
#  'asiacameroonmiddle': 1,
#  'africacanadanorthern': 1,
#  'americacayman': 1,
#  'islandscaribbeancentral': 1,
#  'republicmiddle': 1,
#  'africachadmiddle': 1,
#  'africachannel': 1,
#  'europechilesouth': 1,
#  'americachinaeastern': 1,
#  'macao': 1,
#  'asiacolombiasouth': 1,
#  'americacomoroseastern': 1,
#  'africacongomiddle': 1,
#  'africacook': 1,
#  'islandspolynesiacosta': 1,
#  'ricacentral': 1,
#  'americacroatiasouthern': 1,
#  'asiaczechiaeastern': 1,
#  'europecôte': 1,
#  'ivoirewestern': 1,
#  'africademocratic': 1,
#  'asiademocratic': 1,
#  'congomiddle': 1,
#  'africadenmarknorthern': 1,
#  'europedjiboutieastern': 1,
#  'americaegyptnorthern': 1,
#  'africael': 1,
#  'salvadorcentral': 1,
#  'americaequatorial': 1,
#  'guineamiddle': 1,
#  'africaeritreaeastern': 1,
#  'africaestonianorthern': 1,
#  'europeethiopiaeastern': 1,
#  'africafalkland': 1,
#  'malvinas': 1,
#  'americafaroe': 1,
#  'europefrancewestern': 1,
#  'europefrench': 1,
#  'guianasouth': 1,
#  'americafrench': 1,
#  'africagambiawestern': 1,
#  'africageorgiawestern': 1,
#  'asiagermanywestern': 1,
#  'europeghanawestern': 1,
#  'africagibraltarsouthern': 1,
#  'europegreecesouthern': 1,
#  'europegreenlandnorthern': 1,
#  'americaguineawestern': 1,
#  'africaguyanasouth': 1,
#  'americahaiticaribbeanholy': 1,
#  'seesouthern': 1,
#  'europehondurascentral': 1,
#  'americahungaryeastern': 1,
#  'europeicelandnorthern': 1,
#  'europeindiasouthern': 1,
#  'asiairan': 1,
#  'asiairaqwestern': 1,
#  'asiairelandnorthern': 1,
#  'europeisle': 1,
#  'mannorthern': 1,
#  'europeisraelwestern': 1,
#  'asiaitalysouthern': 1,
#  'asiajordanwestern': 1,
#  'asiakazakhstancentral': 1,
#  'asiakenyaeastern': 1,
#  'asiakyrgyzstancentral': 1,
#  'asialao': 1,
#  'republicsouth-eastern': 1,
#  'asialatvianorthern': 1,
#  'europelebanonwestern': 1,
#  'asialesothosouthern': 1,
#  'africaliberiawestern': 1,
#  'africalibyanorthern': 1,
#  'europelithuanianorthern': 1,
#  'europeluxembourgwestern': 1,
#  'europemadagascareastern': 1,
#  'africamalawieastern': 1,
#  'asiamaldivessouthern': 1,
#  'asiamaliwestern': 1,
#  'africamaltasouthern': 1,
#  'europemarshall': 1,
#  'africamauritiuseastern': 1,
#  'africamayotteeastern': 1,
#  'africamexicocentral': 1,
#  'americamicronesia': 1,
#  'federated': 1,
#  'micronesiamonacowestern': 1,
#  'europemongoliaeastern': 1,
#  'asiamontenegrosouthern': 1,
#  'africamozambiqueeastern': 1,
#  'asianamibiasouthern': 1,
#  'asianetherlandswestern': 1,
#  'europenew': 1,
#  'caledoniamelanesianew': 1,
#  'americanigerwestern': 1,
#  'africanigeriawestern': 1,
#  'europeomanwestern': 1,
#  'asiapakistansouthern': 1,
#  'americapapua': 1,
#  'americaperusouth': 1,
#  'asiapolandeastern': 1,
#  'europeportugalsouthern': 1,
#  'europepuerto': 1,
#  'ricocaribbeanqatarwestern': 1,
#  'moldovaeastern': 1,
#  'europeromaniaeastern': 1,
#  'europerussian': 1,
#  'federationeastern': 1,
#  'europerwandaeastern': 1,
#  'africaréunioneastern': 1,
#  'helenawestern': 1,
#  'neviscaribbeansaint': 1,
#  'luciacaribbeansaint': 1,
#  'miquelonnorthern': 1,
#  'americasaint': 1,
#  'marinosouthern': 1,
#  'europesao': 1,
#  'tome': 1,
#  'principemiddle': 1,
#  'africasaudi': 1,
#  'arabiawestern': 1,
#  'asiasenegalwestern': 1,
#  'africaserbiasouthern': 1,
#  'europeseychelleseastern': 1,
#  'africasierra': 1,
#  'leonewestern': 1,
#  'asiasint': 1,
#  'maarten': 1,
#  'caribbeanslovakiaeastern': 1,
#  'europesloveniasouthern': 1,
#  'europesolomon': 1,
#  'africasouthern': 1,
#  'sudaneastern': 1,
#  'africaspainsouthern': 1,
#  'europesri': 1,
#  'lankasouthern': 1,
#  'asiastate': 1,
#  'palestinewestern': 1,
#  'asiasudannorthern': 1,
#  'africasurinamesouth': 1,
#  'americaswazilandsouthern': 1,
#  'africaswedennorthern': 1,
#  'europeswitzerlandwestern': 1,
#  'europesyrian': 1,
#  'republicwestern': 1,
#  'asiatajikistancentral': 1,
#  'asiathailandsouth-eastern': 1,
#  'asiathe': 1,
#  'macedoniasouthern': 1,
#  'asiatogowestern': 1,
#  'africaturkeywestern': 1,
#  'asiaturkmenistancentral': 1,
#  'asiaturks': 1,
#  'africaukraineeastern': 1,
#  'emirateswestern': 1,
#  'asiaunited': 1,
#  'kingdomnorthern': 1,
#  'tanzaniaeastern': 1,
#  'africaunited': 1,
#  'islandscaribbeanunited': 1,
#  'americanorthern': 1,
#  'americauruguaysouth': 1,
#  'americauzbekistancentral': 1,
#  'bolivarian': 1,
#  'americaviet': 1,
#  'namsouth-eastern': 1,
#  'asiawallis': 1,
#  'futuna': 1,
#  'islandspolynesiawestern': 1,
#  'saharanorthern': 1,
#  'africayemenwestern': 1,
#  'asiazambiaeastern': 1,
#  'africazimbabweeastern': 1,
#  '8-10': 1,
#  ...}

# %%
len(vocab_count)
# Out:
# 52645

# %%
vocabulary
# Out:
# ['',
#  'underestimate',
#  'piece',
#  'rigid',
#  'gradually',
#  'repairhow',
#  'gearworkout',
#  'counterknowledge',
#  'fghn2866ppfrigidaire',
#  'lavender',
#  'ratesdescription',
#  'l',
#  'sternocleidomastoid',
#  'james',
#  'semester-based',
#  'code2011',
#  'marxism',
#  'used51',
#  'waterq',
#  'universitytommy',
#  '195°',
#  'upgrades',
#  'debonair',
#  'anarchism',
#  'lips',
#  'pocket',
#  'belize',
#  'over-reaches',
#  'vindicating',
#  'shoeshiking',
#  'twinsanother',
#  'hb',
#  'top-level',
#  'definition1',
#  'españold',
#  'neill',
#  'science301',
#  'sensed',
#  'jepson',
#  'kingdoms',
#  'help11',
#  'motorsport',
#  'circularcrusty',
#  'instead',
#  'nursery',
#  '2011-01-05',
#  'death–for',
#  'elextroencephalogramwhat',
#  'federally',
#  'hymn',
#  'milkfat',
#  'fall-bloomers',
#  'forestall',
#  '0-11',
#  'imagessupport',
#  'glad',
#  'gangsters',
#  'push-pull',
#  'hitranslator',
#  'quail',
#  'elections',
#  'chair',
#  'falleth',
#  'tuma',
#  'yellowproduct',
#  'sleuthbuffaloa',
#  'kislevhanukkah',
#  'gawker',
#  'tjm2',
#  'dickens',
#  'orphus',
#  'iridium-bearing',
#  'custard',
#  'deliverance',
#  'film',
#  'all-day',
#  'computing',
#  'think',
#  'spasticity—an',
#  'safe',
#  'tumultuous',
#  '��am�',
#  'madre',
#  'broadway',
#  '2014-02-24',
#  'magnum',
#  'erosional',
#  'segen',
#  'iyarlag',
#  'speakerssvtranslator',
#  'yog-sothothapril',
#  'orally/iv',
#  'wolfradt',
#  'intemperate',
#  'futile',
#  'excel',
#  'convertingpoints',
#  'nickelodeon',
#  'employmentregister',
#  'africabermudanorthern',
#  '6-8-10',
#  'dulin',
#  'exemption',
#  'reckless',
#  'engineer-generated',
#  'livingston',
#  'gebco',
#  '1530s',
#  'bicentenary',
#  'underrepresented',
#  'termsharetweete-mailmore',
#  'commonest',
#  '2015-10-09',
#  'vistastaysky',
#  'currentresults',
#  'bosnia',
#  'sleipnes',
#  'contributionhow',
#  'argentinian',
#  'maintenant',
#  'dearly',
#  'blender',
#  'scholar↵siemens',
#  'pile',
#  'accountregister',
#  'decanus',
#  'excellentopen',
#  'injections',
#  'accidental',
#  'olympicsquarter-final',
#  'subscriptions',
#  'definition2',
#  'studio4',
#  'fillings',
#  'painful',
#  '2003-07-17',
#  'm�y�x��\\d�',
#  'all—and',
#  'adolfo',
#  'servewaredrinkware',
#  'contributionsthe',
#  'fifth',
#  'dsm-iii',
#  'plot',
#  'cripple',
#  'crumble',
#  'esswc3wh',
#  'tourshady',
#  'erosive',
#  'clothesbaby',
#  'mommy',
#  'columbonbcjack',
#  '1420s',
#  'component',
#  'ephemera',
#  'amplifier',
#  'imprints',
#  'urchin',
#  'lianeads',
#  '�����',
#  'vulgar',
#  'marblesgrace',
#  'cartcustomer',
#  'dubai',
#  'waldman',
#  'jewry',
#  'cerium',
#  'dare',
#  'hulu',
#  'goldwork',
#  '��_ov',
#  'knopf',
#  'easy-to-read',
#  'regret',
#  'formulasexcel',
#  'illinois',
#  'over',
#  '442n',
#  'torture',
#  'tolerances',
#  'sms',
#  'illusion',
#  'kovács',
#  'galipoli',
#  'fair',
#  'mum707307',
#  'caves',
#  'decrees',
#  'four-cornered',
#  'toxicitymedical',
#  'individuals250',
#  'seesaw',
#  'columbuscitiesbexley',
#  'artane',
#  'williston',
#  'healleprosy',
#  'michele1974',
#  'sixthe',
#  'countryunited',
#  'coloradothe',
#  'patterned',
#  'simple',
#  'europealgerianorthern',
#  'bsf',
#  'energy-intensive',
#  'rm-265',
#  'velocity',
#  'hotch',
#  '6k6879',
#  'moreoverviewchristopher',
#  'tracksright',
#  'day3',
#  'deeply',
#  'secondly',
#  'manufacturingthis',
#  'gramatical',
#  'edi',
#  'rh',
#  'marland',
#  'loreto',
#  'businesscore',
#  'tbsp',
#  '10:00share',
#  'thissecurity',
#  'inhibit',
#  'rubins',
#  'b2breps',
#  'newsforyou',
#  'africaserbiasouthern',
#  'digitalizing',
#  'encumbered',
#  'springer/kluwer/plenum',
#  'menupage',
#  '492-1001country',
#  'proclaimingpoints',
#  'brooklyn',
#  'slid',
#  'jetzy',
#  'iti',
#  'focuses',
#  'eof',
#  'enforcement2366',
#  'timesuccessfully',
#  'washoensis',
#  'resolve',
#  'yerushalayim—jerusalem',
#  'ga',
#  'prospectors',
#  'noise-free',
#  'recreation',
#  'champion',
#  'rangetop',
#  'postagefree',
#  '28°f',
#  '2013-09-24',
#  'causative',
#  'micro',
#  '204654cod',
#  'astatine',
#  'chalmers',
#  'education3535',
#  'exaggerating',
#  'brakesadvanced',
#  'terrorist',
#  'imbalances',
#  'rotator',
#  'hotel32waystomakeyousmile',
#  'gerland',
#  'informationlow',
#  '1990s1',
#  'crabapple',
#  'seminars',
#  'premier',
#  'towelbaking',
#  'johnston',
#  'noaa',
#  'bodies-',
#  'adjudged',
#  'oymyakon',
#  'jewelrygold',
#  'self-improvement',
#  'sunshine',
#  'nkc',
#  'turbojet',
#  'toursmonuments',
#  'flatware',
#  '-dē-ăk′',
#  '11chapter',
#  'self-reported',
#  'marquardt',
#  'pagescommon',
#  'adulterate',
#  'passionflower',
#  'tiles',
#  'proceeds',
#  'amazed',
#  'appetiteirregular',
#  'earnings/orders',
#  'companiesinvestment',
#  'helplegal',
#  'handout',
#  '28egg',
#  'ȷ��t',
#  'subjects2',
#  'precursor',
#  'adssortwhat',
#  'casually',
#  'doorthe',
#  'landed',
#  'tibetbiographical',
#  'italics',
#  'looney',
#  'dracula',
#  'sci59',
#  'api',
#  'freeing',
#  'te',
#  'zubkavich',
#  'well-documented',
#  'undergo',
#  'cloud-based',
#  'waterfruit/vegetable',
#  'hashanah—the',
#  '06milk',
#  'finale',
#  'regularly',
#  'strengthenswe',
#  'utc-4',
#  'dressesbaby',
#  'lan',
#  'rapid',
#  'london',
#  '��dx�w�yh�i�',
#  'davor',
#  'eons',
#  'confidential',
#  'motivation',
#  'mcdermont',
#  '2015-04-03',
#  'beded',
#  '�g�̭��z���-��of�',
#  "b'av27",
#  'reservedone-bit',
#  'saith',
#  'languages',
#  '8.what',
#  'vice-president',
#  'instantiated',
#  'hungry',
#  '105-31',
#  'advertisement',
#  'fsa',
#  'non-payment',
#  'brainwashing',
#  'thirty-six',
#  'insecure',
#  'costinha',
#  '297–324',
#  'lo',
#  'conscripts',
#  'truckers',
#  'sonic',
#  'cup2',
#  'core',
#  'trusts',
#  'database16',
#  'swanlike',
#  'injured',
#  'herzl',
#  'led',
#  'headlined',
#  'ligand',
#  'inwoodisland',
#  'novella',
#  'f4d',
#  '1962–1964valentin',
#  'individual',
#  'housecallour',
#  'theplace',
#  'trading',
#  'gatewood',
#  'kingdomparent',
#  'ten-day',
#  'bleedingskipped',
#  'homelessnesspeople',
#  'inhibits',
#  's31',
#  'uninstalling/reinstalling',
#  'mentorship',
#  '�9r�8��',
#  'borderless',
#  'beautyloracmally',
#  'freeconstruction',
#  'embryos',
#  'eswc1',
#  'occurrences',
#  'hell/indianapolis—he',
#  'youtuber',
#  'bmd',
#  'soul',
#  'shunning',
#  'metadatas',
#  'mah',
#  'e/m',
#  'submission',
#  'contradictory',
#  '2016facts',
#  '2013harry',
#  'dunes',
#  'x�',
#  'subvert',
#  'ios6',
#  'ישראל',
#  'messaging',
#  'coruña',
#  'debunk',
#  'pleuropneumonia',
#  'fables',
#  'keyboard',
#  'agosreeharsha',
#  'weeping',
#  'anesthesiologist',
#  'sportif',
#  'grouo',
#  'drinks',
#  'shuttles',
#  'at-fault',
#  'chroniquesduring',
#  'therefore',
#  'checkbook',
#  'variant£34',
#  '����1',
#  'blacks',
#  'k30',
#  'whipped',
#  'angle…more',
#  'corrections',
#  'freshest',
#  'unending',
#  'tribunal',
#  'minnesota',
#  'tax',
#  'defenseless',
#  'midbrain',
#  'barrenottersa',
#  'maximizer',
#  '12-17',
#  'revolution',
#  'gadget',
#  'blemished',
#  'nosdhc',
#  'drizzle',
#  'belonged',
#  'tonkin',
#  '/schaff/the',
#  'life-cycles',
#  'hires',
#  'glean',
#  '7-9',
#  'vehicle—to',
#  'repolarization',
#  'luxury',
#  'shopsnba',
#  'ilxintegra',
#  '08yogurt',
#  '�ߐw�t',
#  'employees',
#  'decornew',
#  'tenderly',
#  'confiscate',
#  'postponed',
#  'gum',
#  'hickory',
#  'blogwhat',
#  'output',
#  'decorated',
#  'wpa-psk',
#  'distorts',
#  'unmyelinated',
#  'kitchens',
#  'baxter',
#  'encryption',
#  "'u1",
#  'moron',
#  '42002did',
#  'proteolytic',
#  'burrito-eating',
#  'coffe',
#  'categorization',
#  'adults',
#  'playmaker',
#  'questionreach',
#  'launches',
#  'allegedly',
#  'pre-game',
#  'tissuemycotic',
#  'benzodiazepine',
#  'facts',
#  'necronomicon',
#  'casablanca',
#  'fellah',
#  'languagethanks',
#  'kingship',
#  'wavelengths',
#  'noses',
#  'frye',
#  '38mm',
#  'reminds',
#  'sizesclasses',
#  'modding',
#  'satanic',
#  'gunfight',
#  'twitching',
#  'choked',
#  'edgy',
#  'greatdepression',
#  '2018new',
#  '.my',
#  'connecticutexperience',
#  'whereof',
#  'peaceful',
#  'forts',
#  '2:50',
#  'bernsenrobert',
#  'movieu',
#  'nagano',
#  'expires',
#  'conversion',
#  'marienburg',
#  'desu',
#  'stopcock',
#  'acre',
#  'capitalism',
#  'h7',
#  'peccatori',
#  'gazzaralarry',
#  'tapeless',
#  'dealsorder',
#  'reversecanopy',
#  '150–1',
#  'compronio',
#  '1802–1880',
#  'banquets',
#  '2013small-scale',
#  'awarding',
#  'exists0',
#  'b.tech',
#  'clings',
#  'logical',
#  'scanners',
#  'on-the-fly',
#  'פסח',
#  '13:47',
#  '2013-03-18',
#  'field',
#  'mhz1-bit',
#  'portion',
#  '2.with',
#  'marketstermdifferences',
#  'withtoni7',
#  'appraisalproject',
#  'christmas2011',
#  'servicehave',
#  'movie',
#  'mao',
#  'adjusted',
#  'downlight',
#  'missteps',
#  'cottages',
#  'passjump',
#  'patternsare',
#  'lip-smacking',
#  'proximate',
#  'abu',
#  '30000note',
#  'pwerful',
#  'digs',
#  'glowing',
#  'frf',
#  'poaching',
#  'samsung',
#  'cucumber',
#  'vern',
#  'ministerialis',
#  'cutting-edge',
#  '390egg',
#  'suctioning',
#  'pc-3000',
#  '26:19',
#  'draining',
#  '5s.g',
#  'performance3',
#  'escaloninternal',
#  '/p/pronounced',
#  'smithyour',
#  'shifted',
#  '�i����m������7�t�',
#  'readhow',
#  'company',
#  'pirates',
#  'overloading',
#  'roosevelt',
#  'liquid-equivalent',
#  'anna',
#  'chromecast-friendly',
#  'dayerror',
#  'explicitly',
#  'iijan',
#  'barbed',
#  'beneath',
#  '_r',
#  'sex-limited',
#  'successive',
#  'affairs',
#  'mph2:00',
#  'massimo',
#  'decoration',
#  'checks',
#  'big-horn',
#  'f-35',
#  'impact',
#  'pharm',
#  'half-time',
#  'suzuka',
#  'effect',
#  'iz',
#  'bbca',
#  'f.environmental',
#  'rawnutrient',
#  'uranium',
#  'asiaturks',
#  'cozy',
#  '2014for',
#  'pozharsky',
#  'termstraight',
#  'remsenburg',
#  'applications',
#  'earliereverquotewin',
#  'shadmand',
#  'a�x',
#  'conservatory',
#  'art1340c',
#  'simplifiera',
#  'elin',
#  'marais',
#  '���x��e�',
#  'trigger',
#  '4��p��',
#  'bookssymptoms',
#  'romanianinvidia30',
#  'change—which',
#  'inventoryinventory',
#  'silicon-controlled',
#  'scissors',
#  'lend',
#  'imputed',
#  'condemns',
#  'logistics',
#  'fwmh',
#  "dĕr'mă-tō-glif'iks",
#  'germany',
#  'destroys',
#  '27th',
#  'flick',
#  'best-known',
#  'ircl',
#  'pajamasboys',
#  'cc',
#  'rsx2003',
#  'oppenheimer',
#  'awsamazon',
#  'unused10',
#  'causey',
#  'fleece',
#  'firstborn',
#  '124m',
#  'grapesshelf',
#  'eds',
#  'aron',
#  'bechtel',
#  'red',
#  'conclusionone',
#  'lamb',
#  'on-call',
#  'comfort-level',
#  'supreme',
#  '2010-08-31',
#  'aumichael',
#  'marriages',
#  'interpreted',
#  'legislations',
#  'advising',
#  '25mm',
#  'crowning',
#  'moody',
#  '9previous',
#  'premature',
#  'desert',
#  '202cheese',
#  'hence',
#  'aches',
#  'punishes',
#  'irvin',
#  'cbnrm',
#  'attendants',
#  't-cell',
#  'cucumberscherry',
#  'intrepid',
#  'rejects',
#  'controversymichael',
#  'kelty',
#  'baltic',
#  'potionturtle',
#  'definitions',
#  'conquered',
#  'unsourced',
#  '�x',
#  'equivalent',
#  'treatmentsearch',
#  '876-5865county',
#  '1romania',
#  'shaving',
#  'reviews1-12-2015',
#  'devore',
#  'cellsthat',
#  'ripple3',
#  'oversimplifying',
#  'kinosh',
#  'linksgeneral',
#  'sportbrave',
#  'apathetic',
#  'shulḥan',
#  'burwell',
#  'circulatory',
#  'sacrificing',
#  'natlhealthystrt',
#  'grotto',
#  'spend',
#  'conducive',
#  'adriatic',
#  'scholar↵bandy',
#  'side-chapels',
#  'environ',
#  'additions',
#  'secondsdodge',
#  '510455',
#  'carlton',
#  'scheme',
#  'education',
#  'petráš',
#  'tekeytbox',
#  'bz',
#  'feasts',
#  'arawak',
#  'holds',
#  'tongues',
#  'talked',
#  'processions',
#  'idahopinus',
#  'warningsdo',
#  'jakobnew',
#  'fines',
#  'antoon',
#  'mlc',
#  'guiscard',
#  'screen',
#  'remote',
#  'popularseason',
#  'marquise',
#  'lam/getty',
#  'stackable',
#  'orthodox',
#  'enforces',
#  'underlie',
#  'windsor',
#  'brienthe',
#  'banging',
#  'northumbria',
#  'pepper',
#  'always-an',
#  'mother-child',
#  'dramascreen',
#  'benefitsmany',
#  '�c�_5�-jz�k4',
#  'vivrette',
#  'mainmay',
#  'checkermedical',
#  '0117https',
#  'ssris',
#  'islipbayport',
#  'mysteriam',
#  'ariela',
#  'quantum',
#  'wordbook',
#  'amiable',
#  '3:30pmbruce',
#  'comprehensible',
#  'triggers',
#  'eicosanoids',
#  'career',
#  'autocracy',
#  'koo',
#  'man',
#  'presented',
#  'hippies',
#  'bartlet',
#  'kittens…a',
#  'traded',
#  'nosotros',
#  'imprinted',
#  'customercross',
#  'backing',
#  '3036-p',
#  'sally',
#  'farthest',
#  'tracy',
#  'whim',
#  '6:25',
#  'geophysical',
#  'burgess',
#  'acid-',
#  'cob',
#  'compacity',
#  'evil',
#  'fghb2866pffrigidaire',
#  'close-quarter',
#  '���k�l',
#  'bothering',
#  'adorable',
#  'e10',
#  'petition',
#  'spz',
#  'reviewvpx',
#  '845',
#  'sense:1',
#  'hoursvascular',
#  '�k��s����k�w',
#  'schlep',
#  'suit',
#  'constricted',
#  'yڳ�����',
#  'favoring',
#  'sasuphan',
#  'goto',
#  'workaholism',
#  'swiftnesspotion',
#  'olympian',
#  'intensity',
#  'classdefinitionrelatively',
#  '1000x',
#  'limping',
#  'friedreich',
#  'chardcarrot',
#  'adventures',
#  'landlords',
#  'stroll',
#  'nosql3',
#  'rocket-firing',
#  'spanishnorth',
#  'distribution2b-1',
#  'pro-inflammatory',
#  'dustrestores',
#  'fungus',
#  'search',
#  'unbelievably',
#  'geonames',
#  'termbuyer',
#  'xm855cartridge',
#  '�m',
#  'automation',
#  'services',
#  'bridges',
#  'developmentquoting',
#  'rebranded',
#  'passnear',
#  'taxable',
#  'historysearchmain',
#  'rationalization',
#  'invidiare',
#  'coast-to-coast',
#  '4129108-6portalsaccess',
#  'seaman',
#  'sancta',
#  'ballers',
#  'playoff',
#  '17:323and',
#  'fem',
#  'bullae',
#  'acid25',
#  'stake',
#  ':31',
#  'e-gift',
#  'noweditwhat',
#  "ma'ar",
#  '70-80',
#  'miele',
#  'hungary',
#  'referenced',
#  'lanthanum',
#  'prone',
#  '1000–1500',
#  'pronunciation8',
#  'mph4:00',
#  'feminine',
#  'diysilver',
#  'nocturnal',
#  'distribution/wholesale',
#  '996–1002',
#  'rituals',
#  'analsysis',
#  'cliche',
#  'tribes',
#  'probonopublico-ga',
#  'grinder',
#  'tetramer',
#  'sciencevoltage',
#  'langland',
#  'december,1992',
#  'factoring',
#  'tirana',
#  'die',
#  '1-1st',
#  'fabrication',
#  "'prides'",
#  'prayerhail',
#  'avoidfatiguecauses',
#  'contributionscan',
#  'everextra',
#  'c.lawson',
#  'combining',
#  'barracuda',
#  'mhz20',
#  'flavored',
#  'sm',
#  'tipos',
#  'sizethe',
#  'plexiglas',
#  'statesswamp',
#  'arterial',
#  'kangaroo',
#  'electricity',
#  'clustera',
#  'filealzip',
#  'sensibly',
#  'bloomersearly-bloomers',
#  'pn',
#  'pathsuse',
#  '13:37',
#  'three-field',
#  'ccn',
#  'interstae',
#  'friesfoot',
#  'distinctively',
#  'made7',
#  'truthout',
#  'bruce',
#  'residence',
#  'pre-empted',
#  'judgments',
#  'ischemia',
#  'mics',
#  'voll',
#  'soothsayers',
#  'usbvendors',
#  'jesusleprosy',
#  'invasions',
#  'doe',
#  'mylan',
#  'fur',
#  'cleaner',
#  'rompersswimsuitshandbags',
#  'santaella-tenorio',
#  'ashkenazim',
#  'pillow',
#  'merrill',
#  'mmu�qk��̦',
#  '����f',
#  'nickluas',
#  'romania2018',
#  'foreshadow',
#  'faqsetup',
#  'tracks',
#  'bhroinne',
#  'engagements',
#  'platformssee',
#  '5-year-old',
#  'endothelial',
#  '—',
#  'deaths',
#  'mixing',
#  'disinfect',
#  'brandsafr',
#  'opto',
#  'guys',
#  'trying',
#  'patchogue',
#  '-download',
#  'hillbillies',
#  'configured',
#  'fifty-three',
#  ...]

# %%
len(vocabulary)
# Out:
# 52645

# %%
tfidf_tran.shape
# Out:
# (496, 52679)

# %%
tfidf.get_feature_names()[:20]
# Out:
# ['',
#  'underestimate',
#  'piece',
#  'rigid',
#  'gradually',
#  'repairhow',
#  'gearworkout',
#  'counterknowledge',
#  'fghn2866ppfrigidaire',
#  'lavender',
#  'ratesdescription',
#  'l',
#  'sternocleidomastoid',
#  'james',
#  'semester-based',
#  'code2011',
#  'marxism',
#  'used51',
#  'waterq',
#  'universitytommy']

# %%
def gen_vector_T(tokens):
    Q = np.zeros((len(vocabulary)))    
    x= tfidf.transform(tokens)
    #print(tokens[0].split(','))
    for token in tokens[0].split(','):
        #print(token)
        try:
            ind = vocabulary.index(token)
            Q[ind]  = x[0, tfidf.vocabulary_[token]]
        except:
            pass
    return Q

# %%
def cosine_sim(a, b):
    cos_sim = np.dot(a, b)/(np.linalg.norm(a)*np.linalg.norm(b))
    return cos_sim

# %%
def cosine_similarity_T(k, query):
    preprocessed_query = re.sub("\W+", " ", query).strip()
    tokens = word_tokenize(str(preprocessed_query))
    q_df = pd.DataFrame(columns=['q_clean'])
    q_df.loc[0,'q_clean'] = ','.join(tokens)
    
    d_cosines = []
    
    query_vector = gen_vector_T(q_df['q_clean'])
    for d in tfidf_tran.A:
        d_cosines.append(cosine_sim(query_vector, d))
                    
    out = np.array(d_cosines).argsort()[-k:][::-1]
    #print("")
    d_cosines.sort()
    a = pd.DataFrame()
    for i,index in enumerate(out):
        a.loc[i,'index'] = str(index)
        a.loc[i,'Url'] = data_train_processed['Url'][index]
        a.loc[i,'Body'] = data_train_processed['Body'][index]
    for j,simScore in enumerate(d_cosines[-k:][::-1]):
        a.loc[j,'Score'] = simScore
    return a

# %%
cosine_similarity_T(10, 'computer science')
# Out:
#   index                                                Url  \
# 0   113  https://www.sciencelearn.org.nz/resources/469-...
# 1   269  http://www.ece.k-state.edu/graduate/grapositio...
# 2   370     https://quizlet.com/38941450/bios-flash-cards/
# 3   102  http://techotv.com/download-upgrade-install-mi...
# 4   426  http://answers.microsoft.com/en-us/windows/for...
# 5   418       http://www.pnas.org/content/107/17/7823.full
# 6   491  http://www.itjobswatch.co.uk/jobs/uk/software%...
# 7    13  http://www.answers.com/Q/What_political_party_...
# 8     9  https://answers.yahoo.com/question/index?qid=2...
# 9   428         http://www.123helpme.com/view.asp?id=77294
#
#                                                 Body     Score
# 0  explore topics explore concepts teacher pldsig...  0.103609
# 1  gra positionsthe department of electrical and ...  0.091667
# 2  33 terms murderangel plusbioslearn flashcards ...  0.054857
# 3  posted on november 28, 2012 by saurabhdownload...  0.048499
# 4  sd seth d asked onnovember 16, 2009q: network ...  0.047920
# 5  pre-columbian agricultural landscapes, ecosyst...  0.043048
# 6  permanent it jobs contract it jobsperiod 6 mon...  0.040352
# 7  why do people belong to political parties?it b...  0.040188
# 8  health other - healthi have trouble swallowing...  0.039698
# 9  definition of military disciplinelength: 894 w...  0.038377

# %%
data_train['Body'][113]
# Out:
# nan
